# %%
# !pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.1.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.2.2-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.15.4 in /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages (from prophet) (1.26.4)
# Collecting matplotlib>=2.0.0 (from prophet)
#   Using cached matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.0.4 in /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages (from prophet) (2.2.2)
# Collecting holidays>=0.25 (from prophet)
#   Downloading holidays-0.48-py3-none-any.whl.metadata (23 kB)
# Collecting tqdm>=4.36.1 (from prophet)
#   Downloading tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.0 MB/s eta 0:00:00
# Collecting importlib-resources (from prophet)
#   Downloading importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: python-dateutil in /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages (from holidays>=0.25->prophet) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib>=2.0.0->prophet)
#   Using cached contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib>=2.0.0->prophet)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=2.0.0->prophet)
#   Using cached fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=2.0.0->prophet)
#   Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (24.0)
# Collecting pillow>=8 (from matplotlib>=2.0.0->prophet)
#   Using cached pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib>=2.0.0->prophet)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Downloading prophet-1.1.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.4/14.4 MB 7.8 MB/s eta 0:00:0000:0100:01
# Downloading cmdstanpy-1.2.2-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 kB 4.5 MB/s eta 0:00:00
# Downloading holidays-0.48-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 4.8 MB/s eta 0:00:0000:0100:01
# Using cached matplotlib-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 3.9 MB/s eta 0:00:00
# Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (305 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.51.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Using cached pillow-10.3.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Downloading stanio-0.5.0-py3-none-any.whl (8.0 kB)
# Installing collected packages: tqdm, stanio, pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.2 contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 holidays-0.48 importlib-resources-6.4.0 kiwisolver-1.4.5 matplotlib-3.8.4 pillow-10.3.0 prophet-1.1.5 pyparsing-3.1.2 stanio-0.5.0 tqdm-4.66.4

# %%
import pandas as pd
from prophet import Prophet

# %%
df = pd.read_csv('https://raw.githubusercontent.com/facebook/prophet/main/examples/example_wp_log_peyton_manning.csv')
df.head()
# Out:
#            ds         y
# 0  2007-12-10  9.590761
# 1  2007-12-11  8.519590
# 2  2007-12-12  8.183677
# 3  2007-12-13  8.072467
# 4  2007-12-14  7.893572

# %%
m = Prophet()
m.fit(df)
# Out:
# 22:34:17 - cmdstanpy - INFO - Chain [1] start processing
# 22:34:18 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.210097    7.525978    8.907088
# 3266 2017-01-16  8.535122    7.820243    9.241264
# 3267 2017-01-17  8.322549    7.634414    9.069499
# 3268 2017-01-18  8.155179    7.416831    8.883350
# 3269 2017-01-19  8.167136    7.428144    8.917147

# %%
fig1 = m.plot(forecast)
# Out:
# /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages/prophet/plot.py:72: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages/prophet/plot.py:73: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.',

# %%
fig2 = m.plot_components(forecast)
# Out:
# /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages/prophet/plot.py:228: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   fcst_t = fcst['ds'].dt.to_pydatetime()
# /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages/prophet/plot.py:351: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name], ls='-', c='#0072B2')
# /home/oscar/escola/python_django/vendas/.venv/lib/python3.10/site-packages/prophet/plot.py:354: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   df_y['ds'].dt.to_pydatetime(), seas[name + '_lower'],

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 from prophet.plot import plot_plotly, plot_components_plotly
# ----> 3 plot_plotly(m, forecast)
#
# File ~/escola/python_django/vendas/.venv/lib/python3.10/site-packages/prophet/plot.py:597, in plot_plotly(m, fcst, uncertainty, plot_cap, trend, changepoints, changepoints_threshold, xlabel, ylabel, figsize)
#     595 data = []
#     596 # Add actual
# --> 597 data.append(go.Scatter(
#     598     name='Actual',
#     599     x=m.history['ds'],
#     600     y=m.history['y'],
#     601     marker=dict(color=actual_color, size=marker_size),
#     602     mode='markers'
#     603 ))
#     604 # Add lower bound
#     605 if uncertainty and m.uncertainty_samples:
#
# NameError: name 'go' is not defined

# %%
plot_components_plotly(m, forecast)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plot_components_plotly(m, forecast)
#
# File ~/escola/python_django/vendas/.venv/lib/python3.10/site-packages/prophet/plot.py:740, in plot_components_plotly(m, fcst, uncertainty, plot_cap, figsize)
#     738 # Identify components to plot and get their Plotly props
#     739 components = {}
# --> 740 components['trend'] = get_forecast_component_plotly_props(
#     741     m, fcst, 'trend', uncertainty, plot_cap)
#     742 if m.train_holiday_names is not None and 'holidays' in fcst:
#     743     components['holidays'] = get_forecast_component_plotly_props(
#     744         m, fcst, 'holidays', uncertainty)
#
# File ~/escola/python_django/vendas/.venv/lib/python3.10/site-packages/prophet/plot.py:877, in get_forecast_component_plotly_props(m, fcst, name, uncertainty, plot_cap)
#     874         text[idxs.astype(bool)] += holiday_feature
#     876 traces = []
# --> 877 traces.append(go.Scatter(
#     878     name=name,
#     879     x=fcst['ds'],
#     880     y=fcst[name],
#     881     mode=mode,
#     882     line=go.scatter.Line(color=prediction_color, width=line_width),
#     883     text=text,
#     884 ))
#     885 if uncertainty and m.uncertainty_samples and (fcst[name + '_upper'] != fcst[name + '_lower']).any():
#     886     if mode == 'markers':
#
# NameError: name 'go' is not defined
