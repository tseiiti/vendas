# %%
# !pip install pymongo
# !pip install faker
# !pip install unidecode
# !pip install pandas
# !pip install openpyxl
# !pip install apyori
# !pip install ipywidgets
# !pip install prophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymongo in /home/oscar/.local/lib/python3.10/site-packages (4.6.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/oscar/.local/lib/python3.10/site-packages (from pymongo) (2.6.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: faker in /home/oscar/.local/lib/python3.10/site-packages (24.9.0)
# Requirement already satisfied: python-dateutil>=2.4 in /home/oscar/.local/lib/python3.10/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: unidecode in /home/oscar/.local/lib/python3.10/site-packages (1.3.8)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/oscar/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/oscar/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/oscar/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/oscar/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in /home/oscar/.local/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /home/oscar/.local/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: apyori in /home/oscar/.local/lib/python3.10/site-packages (1.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /home/oscar/.local/lib/python3.10/site-packages (8.1.2)
# Requirement already satisfied: comm>=0.1.3 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (8.23.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: decorator in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Requirement already satisfied: stack-data in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: typing-extensions in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/oscar/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in /home/oscar/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/oscar/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/oscar/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/oscar/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting prophet
#   Using cached prophet-1.1.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Using cached cmdstanpy-1.2.2-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.15.4 in /home/oscar/.local/lib/python3.10/site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/oscar/.local/lib/python3.10/site-packages (from prophet) (3.8.4)
# Requirement already satisfied: pandas>=1.0.4 in /home/oscar/.local/lib/python3.10/site-packages (from prophet) (2.2.2)
# Collecting holidays>=0.25 (from prophet)
#   Using cached holidays-0.48-py3-none-any.whl.metadata (23 kB)
# Collecting tqdm>=4.36.1 (from prophet)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting importlib-resources (from prophet)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Using cached stanio-0.5.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: python-dateutil in /home/oscar/.local/lib/python3.10/site-packages (from holidays>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (24.0)
# Requirement already satisfied: pillow>=8 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=2.0.0->prophet) (2.4.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.0.4->prophet) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/oscar/.local/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Using cached prophet-1.1.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.4 MB)
# Using cached cmdstanpy-1.2.2-py3-none-any.whl (94 kB)
# Using cached holidays-0.48-py3-none-any.whl (1.0 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached stanio-0.5.0-py3-none-any.whl (8.0 kB)
# Installing collected packages: tqdm, stanio, importlib-resources, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.2 holidays-0.48 importlib-resources-6.4.0 prophet-1.1.5 stanio-0.5.0 tqdm-4.66.4

# %%
from faker import Faker
from pymongo import MongoClient
import random

# %% [markdown]
# ### Faker será usado para criar valores fictícios

# %%
fake = Faker('pt_BR')

# %% [markdown]
# ### MongoDB

# %%
uri = 'mongodb://localhost/'
db = MongoClient(uri)['vendas']

# a quantidade de usuários define também a quantidade representantes
QUANTIDADE_USUARIOS = 10

# %% [markdown]
# # Criar usuários que serão usados como representantes
#
# ## executar usando shell !!!
#     "python manage.py shell"
#
# e depois colar o resultado abaixo

# %%
from unidecode import unidecode

print('from django.contrib.auth.models import User')

for i in range(QUANTIDADE_USUARIOS):
  first_name = fake.first_name()
  last_name = fake.last_name()
  username = unidecode(first_name.split()[0].lower()) + '.'
  username += unidecode(last_name.split()[-1].lower())
  email = username + '@example.com'
  print(f"User.objects.create_user(username='{username}', email='{email}', password='123', is_staff=True, first_name='{first_name}', last_name='{last_name}', )")
print()
# Out:
# from django.contrib.auth.models import User
# User.objects.create_user(username = 'vitoria.mata', email = 'vitoria.mata@example.com', password = '123', is_staff = True, first_name = 'Vitória', last_name = 'da Mata', )
# User.objects.create_user(username = 'agatha.mota', email = 'agatha.mota@example.com', password = '123', is_staff = True, first_name = 'Agatha', last_name = 'da Mota', )
# User.objects.create_user(username = 'agatha.souza', email = 'agatha.souza@example.com', password = '123', is_staff = True, first_name = 'Agatha', last_name = 'Souza', )
# User.objects.create_user(username = 'lavinia.freitas', email = 'lavinia.freitas@example.com', password = '123', is_staff = True, first_name = 'Lavínia', last_name = 'Freitas', )
# User.objects.create_user(username = 'larissa.luz', email = 'larissa.luz@example.com', password = '123', is_staff = True, first_name = 'Larissa', last_name = 'da Luz', )
# User.objects.create_user(username = 'otavio.carvalho', email = 'otavio.carvalho@example.com', password = '123', is_staff = True, first_name = 'Otávio', last_name = 'Carvalho', )
# User.objects.create_user(username = 'nicole.moura', email = 'nicole.moura@example.com', password = '123', is_staff = True, first_name = 'Nicole', last_name = 'Moura', )
# User.objects.create_user(username = 'joao.silveira', email = 'joao.silveira@example.com', password = '123', is_staff = True, first_name = 'João', last_name = 'Silveira', )
# User.objects.create_user(username = 'lara.rocha', email = 'lara.rocha@example.com', password = '123', is_staff = True, first_name = 'Lara', last_name = 'da Rocha', )
# User.objects.create_user(username = 'rafael.sales', email = 'rafael.sales@example.com', password = '123', is_staff = True, first_name = 'Rafael', last_name = 'Sales', )

# %%
from django.contrib.auth.models import User
User.objects.create_user(username = 'vitoria.mata', email = 'vitoria.mata@example.com', password = '123', is_staff = True, first_name = 'Vitória', last_name = 'da Mata', )
User.objects.create_user(username = 'agatha.mota', email = 'agatha.mota@example.com', password = '123', is_staff = True, first_name = 'Agatha', last_name = 'da Mota', )
User.objects.create_user(username = 'agatha.souza', email = 'agatha.souza@example.com', password = '123', is_staff = True, first_name = 'Agatha', last_name = 'Souza', )
User.objects.create_user(username = 'lavinia.freitas', email = 'lavinia.freitas@example.com', password = '123', is_staff = True, first_name = 'Lavínia', last_name = 'Freitas', )
User.objects.create_user(username = 'larissa.luz', email = 'larissa.luz@example.com', password = '123', is_staff = True, first_name = 'Larissa', last_name = 'da Luz', )
User.objects.create_user(username = 'otavio.carvalho', email = 'otavio.carvalho@example.com', password = '123', is_staff = True, first_name = 'Otávio', last_name = 'Carvalho', )
User.objects.create_user(username = 'nicole.moura', email = 'nicole.moura@example.com', password = '123', is_staff = True, first_name = 'Nicole', last_name = 'Moura', )
User.objects.create_user(username = 'joao.silveira', email = 'joao.silveira@example.com', password = '123', is_staff = True, first_name = 'João', last_name = 'Silveira', )
User.objects.create_user(username = 'lara.rocha', email = 'lara.rocha@example.com', password = '123', is_staff = True, first_name = 'Lara', last_name = 'da Rocha', )
User.objects.create_user(username = 'rafael.sales', email = 'rafael.sales@example.com', password = '123', is_staff = True, first_name = 'Rafael', last_name = 'Sales', )

# %% [markdown]
# # Criar representantes e clientes
# necessita de usuários cadastrados

# %%
representantes = []
for user in db['auth_user'].find({"is_superuser": False}):
  clientes = []
  for i in range(random.randrange(1, 6)):
    clientes.append({
      'id': i + 1,
      'nome': f'{fake.company().upper()} {fake.company_suffix().upper()}',
      'cnpj': fake.cnpj(),
      'contato': fake.name(),
      'telefone': fake.cellphone_number(),
      'email': fake.email(),
      'endereco': {
        'logradouro': fake.street_address(),
        'bairro': fake.bairro(),
        'cidade': fake.city(),
        'estado': fake.estado_sigla(),
        'cep': fake.postcode(formatted=True),
      }
    })
  representantes.append({
    'id': user['id'],
    'nome': f"{user['first_name']} {user['last_name']}",
    'cpf': fake.cpf(),
    'nivel': 'pleno',
    'user_id': user['id'],
    'clientes': clientes,
  })
representantes
# Out:
# [{'id': 1,
#   'nome': 'Vitória da Mata',
#   'cpf': '768.410.253-26',
#   'nivel': 'pleno',
#   'user_id': 1,
#   'clientes': [{'id': 1,
#     'nome': 'COSTELA - EI - ME',
#     'cnpj': '20.879.461/0001-93',
#     'contato': 'Sofia Pinto',
#     'telefone': '+55 (54) 90743-7935',
#     'email': 'scaldeira@example.net',
#     'endereco': {'logradouro': 'Recanto Barbosa',
#      'bairro': 'Liberdade',
#      'cidade': 'Alves',
#      'estado': 'MT',
#      'cep': '02032428'}}]},
#  {'id': 2,
#   'nome': 'Agatha da Mota',
#   'cpf': '605.348.271-44',
#   'nivel': 'pleno',
#   'user_id': 2,
#   'clientes': [{'id': 1,
#     'nome': 'BARROS FERNANDES E FILHOS - EI',
#     'cnpj': '58.324.761/0001-89',
#     'contato': 'Alícia Mendes',
#     'telefone': '+55 (33) 9 0144-7774',
#     'email': 'eduardo86@example.org',
#     'endereco': {'logradouro': 'Vila de da Rosa, 35',
#      'bairro': 'Vila Satélite',
#      'cidade': 'Moura',
#      'estado': 'PI',
#      'cep': '84774-194'}},
#    {'id': 2,
#     'nome': 'DA MATA S/A',
#     'cnpj': '17.295.643/0001-02',
#     'contato': 'Milena Teixeira',
#     'telefone': '+55 (070) 92437 2196',
#     'email': 'yfreitas@example.org',
#     'endereco': {'logradouro': 'Rua de Campos',
#      'bairro': 'Ermelinda',
#      'cidade': 'Vieira das Flores',
#      'estado': 'SP',
#      'cep': '46494020'}}]},
#  {'id': 3,
#   'nome': 'Agatha Souza',
#   'cpf': '697.432.158-91',
#   'nivel': 'pleno',
#   'user_id': 3,
#   'clientes': [{'id': 1,
#     'nome': 'CUNHA LTDA.',
#     'cnpj': '64.213.705/0001-70',
#     'contato': 'Luiz Henrique Almeida',
#     'telefone': '+55 (86) 9 3839 7892',
#     'email': 'caio14@example.org',
#     'endereco': {'logradouro': 'Travessa de Nunes, 27',
#      'bairro': 'Carmo',
#      'cidade': 'da Paz de da Cruz',
#      'estado': 'PB',
#      'cep': '87850890'}},
#    {'id': 2,
#     'nome': 'DA LUZ BARROS S/A LTDA.',
#     'cnpj': '05.243.791/0001-02',
#     'contato': 'Letícia Monteiro',
#     'telefone': '+55 95 9 8909 3590',
#     'email': 'acampos@example.net',
#     'endereco': {'logradouro': 'Quadra de Cunha, 85',
#      'bairro': 'São Marcos',
#      'cidade': 'Silveira de Goiás',
#      'estado': 'TO',
#      'cep': '65696836'}}]},
#  {'id': 4,
#   'nome': 'Lavínia Freitas',
#   'cpf': '842.935.107-88',
#   'nivel': 'pleno',
#   'user_id': 4,
#   'clientes': [{'id': 1,
#     'nome': 'NUNES - ME',
#     'cnpj': '43.907.815/0001-61',
#     'contato': 'Srta. Nicole Ramos',
#     'telefone': '+55 88 9 4954 2263',
#     'email': 'apeixoto@example.org',
#     'endereco': {'logradouro': 'Fazenda Cavalcanti, 5',
#      'bairro': 'Estoril',
#      'cidade': 'Santos',
#      'estado': 'RN',
#      'cep': '85932418'}},
#    {'id': 2,
#     'nome': 'REZENDE S/A E FILHOS',
#     'cnpj': '03.429.716/0001-05',
#     'contato': 'Calebe Jesus',
#     'telefone': '+55 (03) 9 5095-3064',
#     'email': 'gustavo08@example.com',
#     'endereco': {'logradouro': 'Vereda de Duarte, 7',
#      'bairro': 'Santa Helena',
#      'cidade': 'Monteiro',
#      'estado': 'SP',
#      'cep': '42795-713'}},
#    {'id': 3,
#     'nome': 'GOMES - EI E FILHOS',
#     'cnpj': '10.425.863/0001-64',
#     'contato': 'Maria Luiza da Paz',
#     'telefone': '+55 (69) 9 8433-3235',
#     'email': 'davi-lucas49@example.net',
#     'endereco': {'logradouro': 'Condomínio Fogaça, 90',
#      'bairro': 'Santa Isabel',
#      'cidade': 'da Mota de Pereira',
#      'estado': 'BA',
#      'cep': '06109-489'}},
#    {'id': 4,
#     'nome': 'SILVEIRA FOGAÇA - ME E FILHOS',
#     'cnpj': '60.195.437/0001-50',
#     'contato': 'Sr. Vicente Moraes',
#     'telefone': '+55 (001) 92602-5649',
#     'email': 'pietromelo@example.net',
#     'endereco': {'logradouro': 'Jardim Raul Aragão, 24',
#      'bairro': 'Suzana',
#      'cidade': 'Castro de Correia',
#      'estado': 'MS',
#      'cep': '34032-432'}}]},
#  {'id': 5,
#   'nome': 'Larissa da Luz',
#   'cpf': '863.205.741-35',
#   'nivel': 'pleno',
#   'user_id': 5,
#   'clientes': [{'id': 1,
#     'nome': 'FERNANDES - EI S.A.',
#     'cnpj': '68.371.054/0001-05',
#     'contato': 'Sra. Alícia Cunha',
#     'telefone': '+55 (022) 97949 0515',
#     'email': 'vieiravalentina@example.net',
#     'endereco': {'logradouro': 'Parque Carvalho, 48',
#      'bairro': 'São Cristóvão',
#      'cidade': 'Mendes Grande',
#      'estado': 'RS',
#      'cep': '77067-802'}},
#    {'id': 2,
#     'nome': 'CASTRO S.A.',
#     'cnpj': '76.183.524/0001-27',
#     'contato': 'Sophia Cunha',
#     'telefone': '+55 (54) 92602 3840',
#     'email': 'pcampos@example.com',
#     'endereco': {'logradouro': 'Feira Fernandes, 3',
#      'bairro': 'Vila Antena Montanhês',
#      'cidade': 'Ribeiro do Oeste',
#      'estado': 'AL',
#      'cep': '03388236'}},
#    {'id': 3,
#     'nome': 'CORREIA DAS NEVES - ME - ME',
#     'cnpj': '09.625.817/0001-20',
#     'contato': 'Sra. Cecília Martins',
#     'telefone': '+55 (34) 98519 1824',
#     'email': 'da-conceicaoana@example.net',
#     'endereco': {'logradouro': 'Sítio de Martins, 898',
#      'bairro': 'Alta Tensão 1ª Seção',
#      'cidade': 'Correia de da Luz',
#      'estado': 'PB',
#      'cep': '99205-412'}}]},
#  {'id': 6,
#   'nome': 'Otávio Carvalho',
#   'cpf': '769.248.513-55',
#   'nivel': 'pleno',
#   'user_id': 6,
#   'clientes': [{'id': 1,
#     'nome': 'ARAGÃO FREITAS - ME LTDA.',
#     'cnpj': '42.087.963/0001-14',
#     'contato': 'João Vitor da Conceição',
#     'telefone': '+55 (025) 91263 0450',
#     'email': 'monteirootavio@example.net',
#     'endereco': {'logradouro': 'Estrada de Cavalcanti, 15',
#      'bairro': 'Vila Betânia',
#      'cidade': 'Moraes de da Cunha',
#      'estado': 'AC',
#      'cep': '41876599'}}]},
#  {'id': 7,
#   'nome': 'Nicole Moura',
#   'cpf': '301.927.685-30',
#   'nivel': 'pleno',
#   'user_id': 7,
#   'clientes': [{'id': 1,
#     'nome': 'VIANA - EI',
#     'cnpj': '92.105.683/0001-60',
#     'contato': 'Enrico Ferreira',
#     'telefone': '+55 (20) 9 8304 9024',
#     'email': 'mda-cunha@example.net',
#     'endereco': {'logradouro': 'Estação Cauã Araújo, 510',
#      'bairro': 'Ápia',
#      'cidade': 'Peixoto',
#      'estado': 'RJ',
#      'cep': '18079-032'}},
#    {'id': 2,
#     'nome': 'MELO CALDEIRA - EI S/A',
#     'cnpj': '19.670.453/0001-53',
#     'contato': 'Paulo da Luz',
#     'telefone': '+55 32 94032-7848',
#     'email': 'teixeiracaroline@example.org',
#     'endereco': {'logradouro': 'Lago de Carvalho',
#      'bairro': 'Boa Viagem',
#      'cidade': 'Caldeira',
#      'estado': 'RR',
#      'cep': '30716085'}},
#    {'id': 3,
#     'nome': 'SANTOS MORAES S/A E FILHOS',
#     'cnpj': '56.932.174/0001-47',
#     'contato': 'Natália Costa',
#     'telefone': '+55 (82) 9 5758 7527',
#     'email': 'stephanypinto@example.net',
#     'endereco': {'logradouro': 'Vereda de Vieira',
#      'bairro': 'Esplanada',
#      'cidade': 'Peixoto',
#      'estado': 'MT',
#      'cep': '01619909'}}]},
#  {'id': 8,
#   'nome': 'João Silveira',
#   'cpf': '692.431.075-34',
#   'nivel': 'pleno',
#   'user_id': 8,
#   'clientes': [{'id': 1,
#     'nome': 'CARDOSO DA ROSA E FILHOS S.A.',
#     'cnpj': '06.317.482/0001-94',
#     'contato': 'Maria Alice Cardoso',
#     'telefone': '+55 (001) 97871 6699',
#     'email': 'costayago@example.org',
#     'endereco': {'logradouro': 'Vila Benício Alves, 16',
#      'bairro': 'Maria Virgínia',
#      'cidade': 'Ribeiro da Mata',
#      'estado': 'PA',
#      'cep': '81217405'}}]},
#  {'id': 9,
#   'nome': 'Lara da Rocha',
#   'cpf': '857.463.210-44',
#   'nivel': 'pleno',
#   'user_id': 9,
#   'clientes': [{'id': 1,
#     'nome': 'ALVES S.A. S.A.',
#     'cnpj': '87.015.426/0001-05',
#     'contato': 'Dr. Lucas Moraes',
#     'telefone': '+55 98 9 6298-2849',
#     'email': 'jesusjuan@example.org',
#     'endereco': {'logradouro': 'Área Vitor Gabriel Dias',
#      'bairro': 'Santa Isabel',
#      'cidade': 'Sales da Serra',
#      'estado': 'BA',
#      'cep': '70118858'}},
#    {'id': 2,
#     'nome': 'CALDEIRA S.A. E FILHOS',
#     'cnpj': '61.872.053/0001-97',
#     'contato': 'Clara Nascimento',
#     'telefone': '+55 (09) 91785-2767',
#     'email': 'ida-mata@example.net',
#     'endereco': {'logradouro': 'Vila de Freitas, 9',
#      'bairro': 'Granja Werneck',
#      'cidade': 'da Cruz',
#      'estado': 'AP',
#      'cep': '81614641'}}]},
#  {'id': 10,
#   'nome': 'Rafael Sales',
#   'cpf': '670.498.521-20',
#   'nivel': 'pleno',
#   'user_id': 10,
#   'clientes': [{'id': 1,
#     'nome': 'PORTO S/A',
#     'cnpj': '78.936.541/0001-13',
#     'contato': 'João Lucas Oliveira',
#     'telefone': '+55 (062) 98012 4769',
#     'email': 'ian37@example.org',
#     'endereco': {'logradouro': 'Trecho Moura, 8',
#      'bairro': 'Jardim Vitoria',
#      'cidade': 'Moraes',
#      'estado': 'RJ',
#      'cep': '54058-016'}},
#    {'id': 2,
#     'nome': 'CASTRO S/A',
#     'cnpj': '87.204.693/0001-12',
#     'contato': 'João Guilherme Barros',
#     'telefone': '+55 (96) 96911 9807',
#     'email': 'vsilva@example.net',
#     'endereco': {'logradouro': 'Lago Vicente Fogaça, 9',
#      'bairro': 'Vila Copasa',
#      'cidade': 'Azevedo Paulista',
#      'estado': 'RR',
#      'cep': '75893920'}},
#    {'id': 3,
#     'nome': 'LOPES MELO - ME S/A',
#     'cnpj': '51.394.827/0001-68',
#     'contato': 'Elisa Novaes',
#     'telefone': '+55 22 9 8852 7970',
#     'email': 'viniciusjesus@example.com',
#     'endereco': {'logradouro': 'Trevo Nicolas Teixeira',
#      'bairro': 'Vila Dos Anjos',
#      'cidade': 'da Rocha do Oeste',
#      'estado': 'SE',
#      'cep': '24457696'}},
#    {'id': 4,
#     'nome': 'MENDES - ME',
#     'cnpj': '67.130.485/0001-09',
#     'contato': 'Henrique da Conceição',
#     'telefone': '+55 (086) 97576-1070',
#     'email': 'ana-beatrizsilveira@example.net',
#     'endereco': {'logradouro': 'Ladeira de Correia',
#      'bairro': 'Maravilha',
#      'cidade': 'Barbosa do Sul',
#      'estado': 'MG',
#      'cep': '46791-951'}},
#    {'id': 5,
#     'nome': 'GONÇALVES LTDA.',
#     'cnpj': '35.704.981/0001-32',
#     'contato': 'Emanuelly Sales',
#     'telefone': '+55 67 9 1868 4648',
#     'email': 'costelarafael@example.org',
#     'endereco': {'logradouro': 'Fazenda Cardoso, 22',
#      'bairro': 'Maravilha',
#      'cidade': 'Moura',
#      'estado': 'RS',
#      'cep': '66513212'}}]}]

# %%
db['venda_representante'].delete_many({})
db['venda_representante'].insert_many(representantes)
# Out:
# InsertManyResult([ObjectId('664802fec744e849a860cdf9'), ObjectId('664802fec744e849a860cdfa'), ObjectId('664802fec744e849a860cdfb'), ObjectId('664802fec744e849a860cdfc'), ObjectId('664802fec744e849a860cdfd'), ObjectId('664802fec744e849a860cdfe'), ObjectId('664802fec744e849a860cdff'), ObjectId('664802fec744e849a860ce00'), ObjectId('664802fec744e849a860ce01'), ObjectId('664802fec744e849a860ce02')], acknowledged=True)

# %%
for e in db['auth_user'].find({"is_superuser": False}):
  print(e)
# Out:
# {'_id': ObjectId('6647f4f75f44ae5407a374b6'), 'id': 1, 'password': 'pbkdf2_sha256$216000$v3r32H8LP84S$hlDvKnl2cwdCFRf/mc2nUkaHmaisFSIDmnB0UJL/CJ8=', 'last_login': datetime.datetime(2024, 5, 18, 1, 14, 44), 'is_superuser': False, 'username': 'vitoria.mata', 'first_name': 'Vitória', 'last_name': 'da Mata', 'email': 'vitoria.mata@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 19)}
# {'_id': ObjectId('6647f4f85f44ae5407a374b7'), 'id': 2, 'password': 'pbkdf2_sha256$216000$xQW0sXQUrHTK$sMxAQXEMJUtwjT1UpdZu9QYbZ2uHC3nBzfAuCQy8uW4=', 'last_login': datetime.datetime(2024, 5, 18, 0, 29, 22, 453000), 'is_superuser': False, 'username': 'agatha.mota', 'first_name': 'Agatha', 'last_name': 'da Mota', 'email': 'agatha.mota@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 19)}
# {'_id': ObjectId('6647f4f85f44ae5407a374b8'), 'id': 3, 'password': 'pbkdf2_sha256$216000$3rLrtnoPCd96$NFVXparTto9qZMhVg+mvZPlGCLIi2umxNYtTFGKddZk=', 'last_login': None, 'is_superuser': False, 'username': 'agatha.souza', 'first_name': 'Agatha', 'last_name': 'Souza', 'email': 'agatha.souza@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 20, 74000)}
# {'_id': ObjectId('6647f4f85f44ae5407a374b9'), 'id': 4, 'password': 'pbkdf2_sha256$216000$69OxJwNP8dju$hFfcwqXrP062vAErs+hvAhvJxsnXV9NyNVfxd0lvTB0=', 'last_login': None, 'is_superuser': False, 'username': 'lavinia.freitas', 'first_name': 'Lavínia', 'last_name': 'Freitas', 'email': 'lavinia.freitas@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 20, 228000)}
# {'_id': ObjectId('6647f4f85f44ae5407a374ba'), 'id': 5, 'password': 'pbkdf2_sha256$216000$vO84gK3EczUI$krSe/nBigRuASks39kfI8oItwdg0jhHFSETDIoy6VUk=', 'last_login': None, 'is_superuser': False, 'username': 'larissa.luz', 'first_name': 'Larissa', 'last_name': 'da Luz', 'email': 'larissa.luz@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 20, 372000)}
# {'_id': ObjectId('6647f4f85f44ae5407a374bb'), 'id': 6, 'password': 'pbkdf2_sha256$216000$RELh4Sf6ohAO$IZc6uwSzhpugoMpUfKJNvqLHPm5n0fnwtEwE7GvjDgI=', 'last_login': None, 'is_superuser': False, 'username': 'otavio.carvalho', 'first_name': 'Otávio', 'last_name': 'Carvalho', 'email': 'otavio.carvalho@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 20, 535000)}
# {'_id': ObjectId('6647f4f85f44ae5407a374bc'), 'id': 7, 'password': 'pbkdf2_sha256$216000$99FAifZsaESq$tPPEALI25j44fw7zzi9BydEVbpys+OjGEQkkh4LbJEo=', 'last_login': None, 'is_superuser': False, 'username': 'nicole.moura', 'first_name': 'Nicole', 'last_name': 'Moura', 'email': 'nicole.moura@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 20, 697000)}
# {'_id': ObjectId('6647f4f85f44ae5407a374bd'), 'id': 8, 'password': 'pbkdf2_sha256$216000$h6vDDFYvSnHl$MBGdOxQfbqSxsVdRBM83D4qUsZ5f36pV1fs8wGaiHSY=', 'last_login': None, 'is_superuser': False, 'username': 'joao.silveira', 'first_name': 'João', 'last_name': 'Silveira', 'email': 'joao.silveira@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 20, 849000)}
# {'_id': ObjectId('6647f4f95f44ae5407a374be'), 'id': 9, 'password': 'pbkdf2_sha256$216000$jP7BFRkm608c$p5FE6sRVijhG6340URGUrabDb8FrvIUJjaRgbbks4Qs=', 'last_login': None, 'is_superuser': False, 'username': 'lara.rocha', 'first_name': 'Lara', 'last_name': 'da Rocha', 'email': 'lara.rocha@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 20, 997000)}
# {'_id': ObjectId('6647f4f95f44ae5407a374bf'), 'id': 10, 'password': 'pbkdf2_sha256$216000$t9fibjOQX9Kx$hlvyBSS7CAb+RjWlP0Jmxmg1VeE58cwwQDYfyIpCTkA=', 'last_login': None, 'is_superuser': False, 'username': 'rafael.sales', 'first_name': 'Rafael', 'last_name': 'Sales', 'email': 'rafael.sales@example.com', 'is_staff': True, 'is_active': True, 'date_joined': datetime.datetime(2024, 5, 18, 0, 23, 21, 134000)}
