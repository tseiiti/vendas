# %%
# !pip install pymongo
# !pip install faker
# !pip install unidecode
# !pip install pandas
# !pip install openpyxl
# !pip install apyori
# !pip install ipywidgets
# !pip install prophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pymongo in /home/oscar/.local/lib/python3.10/site-packages (4.6.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /home/oscar/.local/lib/python3.10/site-packages (from pymongo) (2.6.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: faker in /home/oscar/.local/lib/python3.10/site-packages (24.9.0)
# Requirement already satisfied: python-dateutil>=2.4 in /home/oscar/.local/lib/python3.10/site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: unidecode in /home/oscar/.local/lib/python3.10/site-packages (1.3.8)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/oscar/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.22.4 in /home/oscar/.local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/oscar/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/oscar/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openpyxl in /home/oscar/.local/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /home/oscar/.local/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: apyori in /home/oscar/.local/lib/python3.10/site-packages (1.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipywidgets in /home/oscar/.local/lib/python3.10/site-packages (8.1.2)
# Requirement already satisfied: comm>=0.1.3 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (8.23.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (5.14.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /home/oscar/.local/lib/python3.10/site-packages (from ipywidgets) (3.0.10)
# Requirement already satisfied: decorator in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (2.11.2)
# Requirement already satisfied: stack-data in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: typing-extensions in /home/oscar/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.11.0)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/oscar/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in /home/oscar/.local/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/oscar/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/oscar/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /home/oscar/.local/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting prophet
#   Using cached prophet-1.1.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.5 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Using cached cmdstanpy-1.2.2-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy>=1.15.4 in /home/oscar/.local/lib/python3.10/site-packages (from prophet) (1.26.4)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/oscar/.local/lib/python3.10/site-packages (from prophet) (3.8.4)
# Requirement already satisfied: pandas>=1.0.4 in /home/oscar/.local/lib/python3.10/site-packages (from prophet) (2.2.2)
# Collecting holidays>=0.25 (from prophet)
#   Using cached holidays-0.48-py3-none-any.whl.metadata (23 kB)
# Collecting tqdm>=4.36.1 (from prophet)
#   Using cached tqdm-4.66.4-py3-none-any.whl.metadata (57 kB)
# Collecting importlib-resources (from prophet)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Using cached stanio-0.5.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: python-dateutil in /home/oscar/.local/lib/python3.10/site-packages (from holidays>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (24.0)
# Requirement already satisfied: pillow>=8 in /home/oscar/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->prophet) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib>=2.0.0->prophet) (2.4.7)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.0.4->prophet) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/oscar/.local/lib/python3.10/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)
# Using cached prophet-1.1.5-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.4 MB)
# Using cached cmdstanpy-1.2.2-py3-none-any.whl (94 kB)
# Using cached holidays-0.48-py3-none-any.whl (1.0 MB)
# Using cached tqdm-4.66.4-py3-none-any.whl (78 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached stanio-0.5.0-py3-none-any.whl (8.0 kB)
# Installing collected packages: tqdm, stanio, importlib-resources, holidays, cmdstanpy, prophet
# Successfully installed cmdstanpy-1.2.2 holidays-0.48 importlib-resources-6.4.0 prophet-1.1.5 stanio-0.5.0 tqdm-4.66.4

# %%
from faker import Faker
from pymongo import MongoClient
import random

# %% [markdown]
# ### Faker será usado para criar valores fictícios

# %%
fake = Faker('pt_BR')

# %% [markdown]
# ### MongoDB

# %%
uri = 'mongodb://localhost/'
db = MongoClient(uri)['vendas']

# a quantidade de usuários define também a quantidade representantes
QUANTIDADE_USUARIOS = 10

# %% [markdown]
# # Criar usuários que serão usados como representantes
#
# ## executar usando shell !!!
#     "python manage.py shell"
#
# e depois colar o resultado abaixo

# %%
from unidecode import unidecode

print('from django.contrib.auth.models import User')

for i in range(QUANTIDADE_USUARIOS):
  first_name = fake.first_name()
  last_name = fake.last_name()
  username = unidecode(first_name.split()[0].lower()) + '.'
  username += unidecode(last_name.split()[-1].lower())
  email = username + '@example.com'
  print(f"User.objects.create_user(username='{username}', email='{email}', password='123', is_staff=True, first_name='{first_name}', last_name='{last_name}', )")
print()
# Out:
# from django.contrib.auth.models import User
# User.objects.create_user(username = 'vitoria.mata', email = 'vitoria.mata@example.com', password = '123', is_staff = True, first_name = 'Vitória', last_name = 'da Mata', )
# User.objects.create_user(username = 'agatha.mota', email = 'agatha.mota@example.com', password = '123', is_staff = True, first_name = 'Agatha', last_name = 'da Mota', )
# User.objects.create_user(username = 'agatha.souza', email = 'agatha.souza@example.com', password = '123', is_staff = True, first_name = 'Agatha', last_name = 'Souza', )
# User.objects.create_user(username = 'lavinia.freitas', email = 'lavinia.freitas@example.com', password = '123', is_staff = True, first_name = 'Lavínia', last_name = 'Freitas', )
# User.objects.create_user(username = 'larissa.luz', email = 'larissa.luz@example.com', password = '123', is_staff = True, first_name = 'Larissa', last_name = 'da Luz', )
# User.objects.create_user(username = 'otavio.carvalho', email = 'otavio.carvalho@example.com', password = '123', is_staff = True, first_name = 'Otávio', last_name = 'Carvalho', )
# User.objects.create_user(username = 'nicole.moura', email = 'nicole.moura@example.com', password = '123', is_staff = True, first_name = 'Nicole', last_name = 'Moura', )
# User.objects.create_user(username = 'joao.silveira', email = 'joao.silveira@example.com', password = '123', is_staff = True, first_name = 'João', last_name = 'Silveira', )
# User.objects.create_user(username = 'lara.rocha', email = 'lara.rocha@example.com', password = '123', is_staff = True, first_name = 'Lara', last_name = 'da Rocha', )
# User.objects.create_user(username = 'rafael.sales', email = 'rafael.sales@example.com', password = '123', is_staff = True, first_name = 'Rafael', last_name = 'Sales', )

# %%
from django.contrib.auth.models import User
User.objects.create_user(username = 'vitoria.mata', email = 'vitoria.mata@example.com', password = '123', is_staff = True, first_name = 'Vitória', last_name = 'da Mata', )
User.objects.create_user(username = 'agatha.mota', email = 'agatha.mota@example.com', password = '123', is_staff = True, first_name = 'Agatha', last_name = 'da Mota', )
User.objects.create_user(username = 'agatha.souza', email = 'agatha.souza@example.com', password = '123', is_staff = True, first_name = 'Agatha', last_name = 'Souza', )
User.objects.create_user(username = 'lavinia.freitas', email = 'lavinia.freitas@example.com', password = '123', is_staff = True, first_name = 'Lavínia', last_name = 'Freitas', )
User.objects.create_user(username = 'larissa.luz', email = 'larissa.luz@example.com', password = '123', is_staff = True, first_name = 'Larissa', last_name = 'da Luz', )
User.objects.create_user(username = 'otavio.carvalho', email = 'otavio.carvalho@example.com', password = '123', is_staff = True, first_name = 'Otávio', last_name = 'Carvalho', )
User.objects.create_user(username = 'nicole.moura', email = 'nicole.moura@example.com', password = '123', is_staff = True, first_name = 'Nicole', last_name = 'Moura', )
User.objects.create_user(username = 'joao.silveira', email = 'joao.silveira@example.com', password = '123', is_staff = True, first_name = 'João', last_name = 'Silveira', )
User.objects.create_user(username = 'lara.rocha', email = 'lara.rocha@example.com', password = '123', is_staff = True, first_name = 'Lara', last_name = 'da Rocha', )
User.objects.create_user(username = 'rafael.sales', email = 'rafael.sales@example.com', password = '123', is_staff = True, first_name = 'Rafael', last_name = 'Sales', )

# %% [markdown]
# # Criar representantes e clientes
# necessita de usuários cadastrados

# %%
representantes = []
for user in db['auth_user'].find({ 'id': { '$gt': 1 }}):
  clientes = []
  for i in range(random.randrange(1, 6)):
    clientes.append({
      'id': i + 1,
      'nome': f'{fake.company().upper()} {fake.company_suffix().upper()}',
      'cnpj': fake.cnpj(),
      'contato': fake.name(),
      'telefone': fake.cellphone_number(),
      'email': fake.email(),
      'endereco': {
        'logradouro': fake.street_address(),
        'bairro': fake.bairro(),
        'cidade': fake.city(),
        'estado': fake.estado_sigla(),
        'cep': fake.postcode(formatted=True),
      }
    })
  representantes.append({
    'id': user['id'],
    'nome': f"{user['first_name']} {user['last_name']}",
    'cpf': fake.cpf(),
    'nivel': 'pleno',
    'user_id': user['id'],
    'clientes': clientes,
  })
representantes
# Out:
# [{'id': 2,
#   'nome': 'Vitória da Mata',
#   'cpf': '394.856.270-92',
#   'nivel': 'pleno',
#   'user_id': 2,
#   'clientes': [{'id': 1,
#     'nome': 'CAVALCANTI NASCIMENTO LTDA. E FILHOS',
#     'cnpj': '26.357.418/0001-44',
#     'contato': 'Isabel Pereira',
#     'telefone': '+55 (071) 94917 7434',
#     'email': 'rebecaaragao@example.com',
#     'endereco': {'logradouro': 'Praia João Lucas Costa, 1',
#      'bairro': 'Madri',
#      'cidade': 'Duarte',
#      'estado': 'RJ',
#      'cep': '32450000'}},
#    {'id': 2,
#     'nome': 'ALVES S.A.',
#     'cnpj': '72.451.096/0001-15',
#     'contato': 'Enzo Gabriel das Neves',
#     'telefone': '+55 (56) 99716 3600',
#     'email': 'uribeiro@example.org',
#     'endereco': {'logradouro': 'Estrada Nascimento',
#      'bairro': 'Vila Vista Alegre',
#      'cidade': 'Correia Verde',
#      'estado': 'ES',
#      'cep': '59959-829'}},
#    {'id': 3,
#     'nome': 'TEIXEIRA LTDA.',
#     'cnpj': '14.073.965/0001-19',
#     'contato': 'Ana Sophia Farias',
#     'telefone': '+55 (25) 9 2037 9115',
#     'email': 'mfarias@example.org',
#     'endereco': {'logradouro': 'Fazenda Rezende, 75',
#      'bairro': 'Vila São Geraldo',
#      'cidade': 'Monteiro das Flores',
#      'estado': 'RR',
#      'cep': '87588-976'}},
#    {'id': 4,
#     'nome': 'PINTO GOMES - ME LTDA.',
#     'cnpj': '15.376.480/0001-67',
#     'contato': 'Carlos Eduardo Fogaça',
#     'telefone': '+55 74 9 2107-6637',
#     'email': 'ada-paz@example.org',
#     'endereco': {'logradouro': 'Rua de Melo, 40',
#      'bairro': 'Vila Coqueiral',
#      'cidade': 'Peixoto de Oliveira',
#      'estado': 'AC',
#      'cep': '60678389'}},
#    {'id': 5,
#     'nome': 'LIMA S/A S.A.',
#     'cnpj': '35.928.076/0001-66',
#     'contato': 'Luna Araújo',
#     'telefone': '+55 (53) 95266 8734',
#     'email': 'mgoncalves@example.net',
#     'endereco': {'logradouro': 'Morro Calebe Monteiro, 31',
#      'bairro': 'Vila Calafate',
#      'cidade': 'Azevedo',
#      'estado': 'PA',
#      'cep': '19006754'}}]},
#  {'id': 3,
#   'nome': 'Agatha da Mota',
#   'cpf': '184.250.697-85',
#   'nivel': 'pleno',
#   'user_id': 3,
#   'clientes': [{'id': 1,
#     'nome': 'GOMES - ME',
#     'cnpj': '49.732.685/0001-50',
#     'contato': 'Maria Fernanda Barbosa',
#     'telefone': '+55 19 9 8302 4757',
#     'email': 'laisferreira@example.com',
#     'endereco': {'logradouro': 'Jardim Lopes, 734',
#      'bairro': 'Vila Aeroporto',
#      'cidade': 'Caldeira das Pedras',
#      'estado': 'CE',
#      'cep': '86027087'}},
#    {'id': 2,
#     'nome': 'FREITAS E FILHOS S/A',
#     'cnpj': '45.370.218/0001-76',
#     'contato': 'Alana Peixoto',
#     'telefone': '+55 (96) 98425 1385',
#     'email': 'avieira@example.com',
#     'endereco': {'logradouro': 'Recanto Azevedo, 20',
#      'bairro': 'Alípio De Melo',
#      'cidade': 'Melo',
#      'estado': 'SE',
#      'cep': '24792-926'}},
#    {'id': 3,
#     'nome': 'DA MATA S.A.',
#     'cnpj': '17.809.452/0001-11',
#     'contato': 'Sra. Eloah Ribeiro',
#     'telefone': '+55 (60) 95128-9559',
#     'email': 'fernandocastro@example.net',
#     'endereco': {'logradouro': 'Colônia Silva, 20',
#      'bairro': 'Mangueiras',
#      'cidade': 'da Mata Alegre',
#      'estado': 'SP',
#      'cep': '24516-277'}}]},
#  {'id': 4,
#   'nome': 'Agatha Souza',
#   'cpf': '269.705.318-21',
#   'nivel': 'pleno',
#   'user_id': 4,
#   'clientes': [{'id': 1,
#     'nome': 'JESUS S.A. - EI',
#     'cnpj': '03.572.614/0001-36',
#     'contato': 'Dra. Evelyn da Cruz',
#     'telefone': '+55 (39) 9 2507-3864',
#     'email': 'silveiradavi-lucas@example.org',
#     'endereco': {'logradouro': 'Lagoa Costa, 416',
#      'bairro': 'Dom Silverio',
#      'cidade': 'da Cruz do Campo',
#      'estado': 'MG',
#      'cep': '47567236'}},
#    {'id': 2,
#     'nome': 'PEREIRA GONÇALVES LTDA. LTDA.',
#     'cnpj': '07.132.895/0001-67',
#     'contato': 'Lavínia Teixeira',
#     'telefone': '+55 (29) 96658-1730',
#     'email': 'uda-costa@example.org',
#     'endereco': {'logradouro': 'Distrito Thomas Alves, 37',
#      'bairro': 'Gameleira',
#      'cidade': 'Silva Grande',
#      'estado': 'PE',
#      'cep': '64265295'}},
#    {'id': 3,
#     'nome': 'CARVALHO LTDA. S.A.',
#     'cnpj': '27.416.850/0001-21',
#     'contato': 'Danilo Pires',
#     'telefone': '+55 (77) 9 3265 6069',
#     'email': 'joao-miguel55@example.net',
#     'endereco': {'logradouro': 'Campo Vieira, 84',
#      'bairro': 'Glória',
#      'cidade': 'Fogaça de da Luz',
#      'estado': 'PE',
#      'cep': '33531301'}},
#    {'id': 4,
#     'nome': 'FARIAS COSTELA S/A S.A.',
#     'cnpj': '47.602.859/0001-34',
#     'contato': 'Antônio Cunha',
#     'telefone': '+55 (03) 9 4940-1606',
#     'email': 'isis58@example.net',
#     'endereco': {'logradouro': 'Feira Gonçalves, 72',
#      'bairro': 'Vila Batik',
#      'cidade': 'Almeida',
#      'estado': 'AC',
#      'cep': '58092711'}},
#    {'id': 5,
#     'nome': 'DA CUNHA E FILHOS LTDA.',
#     'cnpj': '67.214.853/0001-05',
#     'contato': 'Enzo Gabriel Carvalho',
#     'telefone': '+55 03 92486-6949',
#     'email': 'danielgomes@example.org',
#     'endereco': {'logradouro': 'Viaduto de Campos, 6',
#      'bairro': 'Vila Das Oliveiras',
#      'cidade': 'Oliveira',
#      'estado': 'SE',
#      'cep': '74126689'}}]},
#  {'id': 5,
#   'nome': 'Lavínia Freitas',
#   'cpf': '279.453.681-82',
#   'nivel': 'pleno',
#   'user_id': 5,
#   'clientes': [{'id': 1,
#     'nome': 'COSTELA S.A.',
#     'cnpj': '78.165.230/0001-06',
#     'contato': 'Sra. Bianca Sales',
#     'telefone': '+55 (83) 9 7349 1766',
#     'email': 'da-cruzesther@example.org',
#     'endereco': {'logradouro': 'Fazenda de Cardoso, 523',
#      'bairro': 'Mala E Cuia',
#      'cidade': 'das Neves',
#      'estado': 'MS',
#      'cep': '20569-128'}}]},
#  {'id': 6,
#   'nome': 'Larissa da Luz',
#   'cpf': '032.541.986-89',
#   'nivel': 'pleno',
#   'user_id': 6,
#   'clientes': [{'id': 1,
#     'nome': 'NASCIMENTO LTDA. E FILHOS',
#     'cnpj': '73.965.081/0001-38',
#     'contato': 'Nicolas Porto',
#     'telefone': '+55 05 97921-5171',
#     'email': 'levi85@example.org',
#     'endereco': {'logradouro': 'Sítio de Aragão, 10',
#      'bairro': 'São Bernardo',
#      'cidade': 'Duarte',
#      'estado': 'PE',
#      'cep': '84746-707'}},
#    {'id': 2,
#     'nome': 'DA MOTA S.A.',
#     'cnpj': '46.182.530/0001-07',
#     'contato': 'Maria Sophia Mendes',
#     'telefone': '+55 (26) 95048 1664',
#     'email': 'ycaldeira@example.com',
#     'endereco': {'logradouro': 'Passarela Pires, 90',
#      'bairro': 'Xodo-Marize',
#      'cidade': 'das Neves Alegre',
#      'estado': 'RR',
#      'cep': '78608477'}}]},
#  {'id': 7,
#   'nome': 'Otávio Carvalho',
#   'cpf': '803.564.127-17',
#   'nivel': 'pleno',
#   'user_id': 7,
#   'clientes': [{'id': 1,
#     'nome': 'DA COSTA DA MATA - ME - ME',
#     'cnpj': '15.867.902/0001-05',
#     'contato': 'João Miguel da Luz',
#     'telefone': '+55 (047) 93020-4155',
#     'email': 'jesusstella@example.org',
#     'endereco': {'logradouro': 'Vereda de Correia, 84',
#      'bairro': 'São Bernardo',
#      'cidade': 'Monteiro Paulista',
#      'estado': 'SP',
#      'cep': '67450628'}},
#    {'id': 2,
#     'nome': 'FARIAS PEREIRA LTDA. S.A.',
#     'cnpj': '67.029.314/0001-98',
#     'contato': 'Dr. Henrique Aragão',
#     'telefone': '+55 (027) 98320-1713',
#     'email': 'ana-livia17@example.org',
#     'endereco': {'logradouro': 'Lago Eduarda da Cruz, 29',
#      'bairro': 'Caiçaras',
#      'cidade': 'da Mata',
#      'estado': 'GO',
#      'cep': '96657308'}},
#    {'id': 3,
#     'nome': 'MOURA - EI - EI',
#     'cnpj': '46.819.527/0001-43',
#     'contato': 'Dra. Giovanna Moura',
#     'telefone': '+55 (078) 98520-7416',
#     'email': 'tda-mata@example.org',
#     'endereco': {'logradouro': 'Colônia de Castro, 40',
#      'bairro': 'Vila De Sá',
#      'cidade': 'Barbosa',
#      'estado': 'AP',
#      'cep': '90863-281'}},
#    {'id': 4,
#     'nome': 'DA CONCEIÇÃO LTDA.',
#     'cnpj': '31.589.724/0001-46',
#     'contato': 'Davi Lucca Souza',
#     'telefone': '+55 (71) 9 5419-4642',
#     'email': 'hda-rosa@example.org',
#     'endereco': {'logradouro': 'Praia Carvalho, 46',
#      'bairro': 'Serra Verde',
#      'cidade': 'Vieira de Gomes',
#      'estado': 'RS',
#      'cep': '75895-889'}},
#    {'id': 5,
#     'nome': 'GOMES - EI E FILHOS',
#     'cnpj': '57.204.931/0001-29',
#     'contato': 'Erick da Luz',
#     'telefone': '+55 (49) 90729-6459',
#     'email': 'ana-claramoraes@example.org',
#     'endereco': {'logradouro': 'Loteamento de da Conceição',
#      'bairro': 'Aparecida 7ª Seção',
#      'cidade': 'Moura',
#      'estado': 'AP',
#      'cep': '12856-492'}}]},
#  {'id': 8,
#   'nome': 'Nicole Moura',
#   'cpf': '263.185.907-30',
#   'nivel': 'pleno',
#   'user_id': 8,
#   'clientes': [{'id': 1,
#     'nome': 'ARAÚJO - EI LTDA.',
#     'cnpj': '62.985.413/0001-20',
#     'contato': 'Rafael da Luz',
#     'telefone': '+55 97 9 1573-5364',
#     'email': 'samuelbarbosa@example.com',
#     'endereco': {'logradouro': 'Jardim de Fernandes, 53',
#      'bairro': 'Vila Nossa Senhora Do Rosário',
#      'cidade': 'Teixeira',
#      'estado': 'RJ',
#      'cep': '47595823'}}]},
#  {'id': 9,
#   'nome': 'João Silveira',
#   'cpf': '296.015.834-24',
#   'nivel': 'pleno',
#   'user_id': 9,
#   'clientes': [{'id': 1,
#     'nome': 'SILVEIRA E FILHOS LTDA.',
#     'cnpj': '64.952.180/0001-94',
#     'contato': 'Sra. Raquel Costa',
#     'telefone': '+55 (22) 9 6656 5565',
#     'email': 'julia95@example.net',
#     'endereco': {'logradouro': 'Recanto Silveira, 861',
#      'bairro': 'Vila Santo Antônio',
#      'cidade': 'da Mata de Fogaça',
#      'estado': 'AL',
#      'cep': '50626-411'}},
#    {'id': 2,
#     'nome': 'NOVAES S/A',
#     'cnpj': '74.193.682/0001-32',
#     'contato': 'Cauê Costela',
#     'telefone': '+55 (52) 92516-1006',
#     'email': 'psales@example.net',
#     'endereco': {'logradouro': 'Estrada Helena Peixoto, 18',
#      'bairro': 'Conjunto Lagoa',
#      'cidade': 'Cardoso',
#      'estado': 'PB',
#      'cep': '89887141'}},
#    {'id': 3,
#     'nome': 'CORREIA S.A.',
#     'cnpj': '45.938.201/0001-72',
#     'contato': 'Eduarda da Paz',
#     'telefone': '+55 57 98878 7072',
#     'email': 'joao-gabrielrodrigues@example.com',
#     'endereco': {'logradouro': 'Praça João Gabriel Ramos, 528',
#      'bairro': 'Vila São Gabriel',
#      'cidade': 'Santos',
#      'estado': 'GO',
#      'cep': '27362-480'}}]},
#  {'id': 10,
#   'nome': 'Lara da Rocha',
#   'cpf': '691.827.405-85',
#   'nivel': 'pleno',
#   'user_id': 10,
#   'clientes': [{'id': 1,
#     'nome': 'CARDOSO PIRES LTDA. S/A',
#     'cnpj': '38.720.164/0001-66',
#     'contato': 'Luna das Neves',
#     'telefone': '+55 39 9 4951 9229',
#     'email': 'emanuellada-cunha@example.net',
#     'endereco': {'logradouro': 'Área João Lucas Teixeira, 86',
#      'bairro': 'União',
#      'cidade': 'da Rocha',
#      'estado': 'SE',
#      'cep': '31845735'}},
#    {'id': 2,
#     'nome': 'DA MATA - EI',
#     'cnpj': '05.496.782/0001-15',
#     'contato': 'Dra. Brenda Melo',
#     'telefone': '+55 90 9 1761-4263',
#     'email': 'correiafelipe@example.org',
#     'endereco': {'logradouro': 'Colônia Lívia Araújo, 27',
#      'bairro': 'Jatobá',
#      'cidade': 'Porto de Santos',
#      'estado': 'SP',
#      'cep': '05018162'}},
#    {'id': 3,
#     'nome': 'VIANA - ME',
#     'cnpj': '72.568.049/0001-56',
#     'contato': 'Thales Cardoso',
#     'telefone': '+55 (10) 9 0859-0687',
#     'email': 'raulda-costa@example.net',
#     'endereco': {'logradouro': 'Campo Luiza Vieira, 41',
#      'bairro': 'Colégio Batista',
#      'cidade': 'Castro do Galho',
#      'estado': 'MG',
#      'cep': '52240908'}},
#    {'id': 4,
#     'nome': 'FREITAS BARROS S/A LTDA.',
#     'cnpj': '75.142.630/0001-08',
#     'contato': 'Sophie Nunes',
#     'telefone': '+55 (70) 94731 4223',
#     'email': 'brendafernandes@example.com',
#     'endereco': {'logradouro': 'Pátio Cecília Teixeira',
#      'bairro': 'Dom Cabral',
#      'cidade': 'Ramos do Campo',
#      'estado': 'BA',
#      'cep': '25908-270'}}]},
#  {'id': 11,
#   'nome': 'Rafael Sales',
#   'cpf': '958.401.327-05',
#   'nivel': 'pleno',
#   'user_id': 11,
#   'clientes': [{'id': 1,
#     'nome': 'MONTEIRO S/A',
#     'cnpj': '39.725.108/0001-87',
#     'contato': 'Joana Vieira',
#     'telefone': '+55 (98) 9 7372 8004',
#     'email': 'sabrinada-conceicao@example.org',
#     'endereco': {'logradouro': 'Conjunto da Mota',
#      'bairro': 'Grota',
#      'cidade': 'Silva',
#      'estado': 'PI',
#      'cep': '00315544'}},
#    {'id': 2,
#     'nome': 'ROCHA NOVAES E FILHOS E FILHOS',
#     'cnpj': '90.268.573/0001-93',
#     'contato': 'João Miguel Gonçalves',
#     'telefone': '+55 (17) 9 4817-2154',
#     'email': 'mpires@example.org',
#     'endereco': {'logradouro': 'Condomínio de Duarte, 62',
#      'bairro': 'Jatobá',
#      'cidade': 'da Rosa',
#      'estado': 'PR',
#      'cep': '39599-600'}},
#    {'id': 3,
#     'nome': 'MORAES S/A - ME',
#     'cnpj': '40.685.917/0001-91',
#     'contato': 'Lorena Costa',
#     'telefone': '+55 (13) 94130-1035',
#     'email': 'uporto@example.net',
#     'endereco': {'logradouro': 'Chácara de Ferreira, 4',
#      'bairro': 'São Damião',
#      'cidade': 'Santos de Souza',
#      'estado': 'RO',
#      'cep': '70354629'}},
#    {'id': 4,
#     'nome': 'DAS NEVES LTDA.',
#     'cnpj': '41.095.867/0001-55',
#     'contato': 'Pietra Nogueira',
#     'telefone': '+55 34 9 5880-1709',
#     'email': 'davi-luccagomes@example.net',
#     'endereco': {'logradouro': 'Núcleo Eduarda da Conceição',
#      'bairro': 'Betânia',
#      'cidade': 'Silva',
#      'estado': 'PA',
#      'cep': '88979153'}}]}]

# %%
db['venda_representante'].delete_many({})
db['venda_representante'].insert_many(representantes)
# Out:
# InsertManyResult([ObjectId('6643f2e81b3d203797729fab'), ObjectId('6643f2e81b3d203797729fac'), ObjectId('6643f2e81b3d203797729fad'), ObjectId('6643f2e81b3d203797729fae'), ObjectId('6643f2e81b3d203797729faf'), ObjectId('6643f2e81b3d203797729fb0'), ObjectId('6643f2e81b3d203797729fb1'), ObjectId('6643f2e81b3d203797729fb2'), ObjectId('6643f2e81b3d203797729fb3'), ObjectId('6643f2e81b3d203797729fb4')], acknowledged=True)
