# %%
from faker import Faker
from pymongo import MongoClient
from datetime import datetime
import pandas as pd
import random

# %%
uri = 'mongodb://localhost/'
db = MongoClient(uri)['vendas']

# a quantidade de usuários define também a quantidade representantes
QUANTIDADE_USUARIOS = 10

# %%
df_ori = pd.read_csv('/home/oscar/escola/dados/Sales_Product_Combined.csv')

# %%
# renomeando campos
df_aux = df_ori.rename(columns={
  'Order ID': 'id', 
  'Product' : 'produto', 
  'Quantity Ordered': 'quantidade', 
  'Price': 'preco', 
  'Order Date': 'data',
  'Time': 'hora',
  'Product Type': 'categoria', 
  'Purchase Address': 'endereco', 
  'City': 'cidade',
})

# criando campo horário
df_aux['horario'] = pd.to_datetime(df_aux['data'] + ' ' + df_aux['hora'], format='%d-%m-%Y %I:%M %p')

# diminuindo quantidade de registros
df_aux['cidade'] = df_aux['cidade'].str.strip()
# df_aux = df_aux.query('horario.dt.year == 2019 and cidade == "San Francisco"')[
df_aux = df_aux.query('horario.dt.year == 2019 and cidade == "Austin"')[
  ['horario', 'produto', 'quantidade', 'preco']
]

# %%
df = df_aux.sort_values('horario')

# campo auxiliar para aleatórios
df['rnd'] = [random.randrange(100) for _ in df.index]

# transferir 25% das vendas dos meses 3, 4 e 5 para os meses 9, 10 e 11
df['horario'] = df['horario'].mask(
  (df['horario'] > pd.to_datetime('01-03-2019', format='%d-%m-%Y')) & 
  (df['horario'] < pd.to_datetime('01-06-2019', format='%d-%m-%Y')) & 
  (df['rnd'] < 25), 
  df['horario'] + pd.DateOffset(months=6))

# transferir 20% das vendas do mês 12 para o mês 1
df['horario'] = df['horario'].mask(
  (df['horario'] > pd.to_datetime('01-12-2019', format='%d-%m-%Y')) & 
  (df['rnd'] < 20), 
  df['horario'] + pd.DateOffset(months=-11))

# distribuir aleatóriamente os registros em 5 anos
df['rnd'] = [random.randrange(100) for _ in df.index]
df['horario'] = df['horario'].mask(
  (df.rnd < 25), 
  df['horario'] + pd.DateOffset(years=2))
df['horario'] = df['horario'].mask(
  (df.rnd >= 25) & 
  (df.rnd < 50),
  df['horario'] + pd.DateOffset(years=3))
df['horario'] = df['horario'].mask(
  (df.rnd >= 50) & 
  (df.rnd < 75),
  df['horario'] + pd.DateOffset(years=4))
df['horario'] = df['horario'].mask(
  (df.rnd >= 75),
  df['horario'] + pd.DateOffset(years=5))

# campo auxiliar de data
df['data'] = pd.to_datetime(df['horario']).dt.date

# distribuir os itens do pedido
df['nota'] = df['horario'].dt.strftime('%Y%m%d-%M').str.slice(stop=10)

# permitir cálculo com o preço
df['preco'] = df['preco'].str.replace(',', '').astype(float)
df['preco'] = df.apply(lambda row: row['preco'] * 10 if row['preco'] < 80 else row['preco'], axis=1)
df['preco'] = df['preco'].round(2)

# calcular aleatóriamente quantidade, mas valores menores tem peso maior
pop = [i + 1 for i in range(40)]
wei = [i * i + 1 for i in range(40, 0, -1)]
df['quantidade'] = random.choices(pop, wei, k=len(df.index))
df['quantidade'] = (df['quantidade'] / (df['quantidade'] * df['preco'] / 10000 + 1).astype(int)).astype(int)
df['total'] = df['quantidade'] * df['preco']
df['total'] = df['total'].round(2)

# renomear produtos
prod = {
  'AA Batteries (4-pack)': 'P01',
  'AAA Batteries (4-pack)': 'P02',
  'Lightning Charging Cable': 'P03',
  'USB-C Charging Cable': 'P04',
  'LG Dryer': 'P05',
  'Apple Airpods Headphones': 'P06',
  'Bose SoundSport Headphones': 'P07',
  'Wired Headphones': 'P08',
  'iPhone': 'P09',
  'Macbook Pro Laptop': 'P10',
  'ThinkPad Laptop': 'P11',
  'LG Washing Machine': 'P12',
  '20in Monitor': 'P13',
  '27in 4K Gaming Monitor': 'P14',
  '27in FHD Monitor': 'P15',
  '34in Ultrawide Monitor': 'P16',
  'Google Phone': 'P17',
  'Vareebadd Phone': 'P18',
  'Flatscreen TV': 'P19',
}
df['produto'] = df.apply(lambda row: prod[row['produto']], axis=1)

df = df[['nota', 'data', 'horario', 'produto', 'quantidade']].sort_values('horario')

# %%
df.groupby(['produto'])['quantidade'].sum()
# Out:
# produto
# P01    11665
# P02    11724
# P03    13320
# P04    12477
# P05      476
# P06     9802
# P07     7239
# P08    11158
# P09     2857
# P10      951
# P11     1306
# P12      186
# P13     2631
# P14     3088
# P15     4001
# P16     3315
# P17     2279
# P18     1002
# P19     2653
# Name: quantidade, dtype: int64

# %%
df.head()
# Out:
#              nota        data             horario produto  quantidade
# 75315  20210101-1  2021-01-01 2021-01-01 10:12:00     P04           9
# 76286  20210101-1  2021-01-01 2021-01-01 13:10:00     P08           1
# 40253  20210101-3  2021-01-01 2021-01-01 20:38:00     P06           6
# 72608  20210101-1  2021-01-01 2021-01-01 23:18:00     P02          25
# 67603  20210102-2  2021-01-02 2021-01-02 01:26:00     P03          11

# %%
b = df[['horario', 'quantidade']]
b.index = df.horario
b.resample(rule='ME', on='horario')['quantidade'].sum()
# Out:
# horario
# 2021-01-31    2028
# 2021-02-28    1809
# 2021-03-31    1670
# 2021-04-30    1580
# 2021-05-31    1875
# 2021-06-30    1884
# 2021-07-31    2083
# 2021-08-31    1681
# 2021-09-30    2255
# 2021-10-31    3671
# 2021-11-30    2998
# 2021-12-31    2857
# 2022-01-31    2237
# 2022-02-28    1429
# 2022-03-31    1345
# 2022-04-30    1949
# 2022-05-31    1415
# 2022-06-30    1941
# 2022-07-31    1928
# 2022-08-31    1817
# 2022-09-30    2152
# 2022-10-31    3613
# 2022-11-30    2892
# 2022-12-31    2856
# 2023-01-31    2041
# 2023-02-28    1706
# 2023-03-31    1637
# 2023-04-30    2137
# 2023-05-31    1408
# 2023-06-30    1941
# 2023-07-31    1750
# 2023-08-31    1576
# 2023-09-30    2230
# 2023-10-31    3419
# 2023-11-30    2531
# 2023-12-31    2498
# 2024-01-31    2402
# 2024-02-29    1715
# 2024-03-31    1882
# 2024-04-30    2113
# 2024-05-31    1816
# 2024-06-30    1494
# 2024-07-31    1991
# 2024-08-31    1518
# 2024-09-30    2106
# 2024-10-31    2973
# 2024-11-30    2586
# 2024-12-31    2695
# Freq: ME, Name: quantidade, dtype: int64

# %%
xls = pd.read_excel('estoque.xlsx')
produtos = []
for i, e in enumerate(xls.to_dict('records')):
  produtos.append({
    'id': i + 1,
    'produto': {
      'marca': {
        'nome': e['marca'],
      },
      'categoria': {
        'titulo': e['categoria'],
      },
      'descricao': e['descricao'],
    },
    'quantidade': e['quantidade'],
    'preco_compra': e['preco_compra'],
    'preco_venda': e['preco_compra'] * 2,
  })

# %%
# df.query('horario > "2023-01-01" and horario < "2024-01-01"')
# df.query('data == "2023-01-01"')
teste = df.query('horario > "2023-01-01" and horario < "2023-01-02"').sort_values(['data', 'nota', 'produto'])

# %%
teste
# Out:
#              nota        data             horario produto  quantidade
# 51148  20230101-0  2023-01-01 2023-01-01 22:06:00     P04          34
# 68358  20230101-0  2023-01-01 2023-01-01 23:08:00     P04           2
# 74264  20230101-0  2023-01-01 2023-01-01 11:00:00     P19           4
# 76404  20230101-1  2023-01-01 2023-01-01 19:11:00     P02          21
# 73463  20230101-1  2023-01-01 2023-01-01 14:12:00     P17           4
# 74670  20230101-2  2023-01-01 2023-01-01 15:27:00     P02          13
# 73698  20230101-3  2023-01-01 2023-01-01 13:30:00     P02          10
# 71977  20230101-3  2023-01-01 2023-01-01 10:32:00     P06          16
# 69596  20230101-3  2023-01-01 2023-01-01 15:39:00     P07          22
# 33341  20230101-4  2023-01-01 2023-01-01 14:41:00     P08           5

# %%
teste.shape
# Out:
# (10, 5)

# %%
representantes = list(db['venda_representante'].find())
representantes
# Out:
# [{'_id': ObjectId('6636a5a6bf67c4821d38e654'),
#   'id': 2,
#   'nome': 'Vitória da Mata',
#   'cpf': '086.925.743-92',
#   'nivel': 'CONFIRMAR',
#   'user_id': 2,
#   'clientes': [{'id': 1,
#     'nome': 'MOURA S/A',
#     'cnpj': '29.468.031/0001-53',
#     'contato': 'Vitor Hugo Barbosa',
#     'telefone': '+55 (079) 91711-6597',
#     'email': 'catarina97@example.net',
#     'endereco': {'logradouro': 'Colônia Nunes, 3',
#      'bairro': 'Candelaria',
#      'cidade': 'Souza',
#      'estado': 'CE',
#      'cep': '13642-215'}},
#    {'id': 2,
#     'nome': 'DA ROCHA S.A.',
#     'cnpj': '85.731.240/0001-19',
#     'contato': 'Sophie Sales',
#     'telefone': '+55 91 98153 8215',
#     'email': 'erodrigues@example.org',
#     'endereco': {'logradouro': 'Conjunto de Pires',
#      'bairro': 'Boa União 1ª Seção',
#      'cidade': 'Porto da Mata',
#      'estado': 'SE',
#      'cep': '70639660'}},
#    {'id': 3,
#     'nome': 'DA CONCEIÇÃO PINTO E FILHOS - EI',
#     'cnpj': '70.359.814/0001-00',
#     'contato': 'Gabrielly Campos',
#     'telefone': '+55 (52) 9 3700 3137',
#     'email': 'costelarafael@example.org',
#     'endereco': {'logradouro': 'Chácara de Castro, 97',
#      'bairro': 'Vitoria',
#      'cidade': 'Moraes da Praia',
#      'estado': 'SC',
#      'cep': '13783106'}},
#    {'id': 4,
#     'nome': 'TEIXEIRA - EI',
#     'cnpj': '17.306.429/0001-04',
#     'contato': 'Catarina da Paz',
#     'telefone': '+55 (53) 9 1110-6167',
#     'email': 'ofreitas@example.org',
#     'endereco': {'logradouro': 'Rodovia da Rocha, 6',
#      'bairro': 'Serra',
#      'cidade': 'Rezende dos Dourados',
#      'estado': 'RJ',
#      'cep': '26778101'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e655'),
#   'id': 3,
#   'nome': 'Agatha da Mota',
#   'cpf': '392.076.548-65',
#   'nivel': 'CONFIRMAR',
#   'user_id': 3,
#   'clientes': [{'id': 1,
#     'nome': 'CASTRO CARDOSO LTDA. - ME',
#     'cnpj': '46.327.180/0001-11',
#     'contato': 'Milena Cavalcanti',
#     'telefone': '+55 11 95662-8018',
#     'email': 'fogacabernardo@example.com',
#     'endereco': {'logradouro': 'Praça de Barros, 53',
#      'bairro': 'Alípio De Melo',
#      'cidade': 'Duarte',
#      'estado': 'RR',
#      'cep': '49057957'}},
#    {'id': 2,
#     'nome': 'SANTOS LTDA. LTDA.',
#     'cnpj': '98.157.640/0001-04',
#     'contato': 'Erick Sales',
#     'telefone': '+55 97 96294 2290',
#     'email': 'flopes@example.org',
#     'endereco': {'logradouro': 'Estrada de da Luz, 43',
#      'bairro': 'Beira Linha',
#      'cidade': 'Lopes de Lopes',
#      'estado': 'CE',
#      'cep': '56234-352'}},
#    {'id': 3,
#     'nome': 'AZEVEDO - EI S.A.',
#     'cnpj': '83.270.591/0001-44',
#     'contato': 'Mirella Mendes',
#     'telefone': '+55 84 95535-9834',
#     'email': 'isabella46@example.net',
#     'endereco': {'logradouro': 'Jardim de Vieira',
#      'bairro': 'Flavio Marques Lisboa',
#      'cidade': 'Pires do Galho',
#      'estado': 'MG',
#      'cep': '88602518'}},
#    {'id': 4,
#     'nome': 'FREITAS E FILHOS E FILHOS',
#     'cnpj': '16.397.405/0001-45',
#     'contato': 'Maria Eduarda Barros',
#     'telefone': '+55 (42) 98280-3515',
#     'email': 'emilly19@example.com',
#     'endereco': {'logradouro': 'Loteamento de Cardoso, 99',
#      'bairro': 'Dom Cabral',
#      'cidade': 'Pinto',
#      'estado': 'MT',
#      'cep': '63096-029'}},
#    {'id': 5,
#     'nome': 'FOGAÇA CARDOSO - EI - EI',
#     'cnpj': '71.359.608/0001-55',
#     'contato': 'Júlia Monteiro',
#     'telefone': '+55 (13) 98565-1115',
#     'email': 'qgoncalves@example.net',
#     'endereco': {'logradouro': 'Aeroporto Amanda Moraes, 35',
#      'bairro': 'Vila Madre Gertrudes 3ª Seção',
#      'cidade': 'Aragão',
#      'estado': 'RJ',
#      'cep': '06792987'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e656'),
#   'id': 4,
#   'nome': 'Agatha Souza',
#   'cpf': '480.193.756-00',
#   'nivel': 'CONFIRMAR',
#   'user_id': 4,
#   'clientes': [{'id': 1,
#     'nome': 'NOGUEIRA LTDA.',
#     'cnpj': '32.671.490/0001-44',
#     'contato': 'Esther Barbosa',
#     'telefone': '+55 40 9 1603-7642',
#     'email': 'benjamin84@example.net',
#     'endereco': {'logradouro': 'Estrada da Conceição, 161',
#      'bairro': 'Vila Paquetá',
#      'cidade': 'Gonçalves',
#      'estado': 'AC',
#      'cep': '42150-252'}},
#    {'id': 2,
#     'nome': 'REZENDE S.A.',
#     'cnpj': '29.645.380/0001-01',
#     'contato': 'Beatriz Silva',
#     'telefone': '+55 (023) 90645-5490',
#     'email': 'iferreira@example.net',
#     'endereco': {'logradouro': 'Lago de Souza, 28',
#      'bairro': 'Funcionários',
#      'cidade': 'Rodrigues de Monteiro',
#      'estado': 'RR',
#      'cep': '00144-315'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e657'),
#   'id': 5,
#   'nome': 'Lavínia Freitas',
#   'cpf': '413.569.820-42',
#   'nivel': 'CONFIRMAR',
#   'user_id': 5,
#   'clientes': [{'id': 1,
#     'nome': 'DA ROCHA LTDA. - ME',
#     'cnpj': '76.401.528/0001-34',
#     'contato': 'Erick da Costa',
#     'telefone': '+55 (088) 99366 1378',
#     'email': 'gviana@example.net',
#     'endereco': {'logradouro': 'Estação Carlos Eduardo Rodrigues, 540',
#      'bairro': 'Betânia',
#      'cidade': 'Peixoto da Praia',
#      'estado': 'DF',
#      'cep': '50769-962'}},
#    {'id': 2,
#     'nome': 'ALVES E FILHOS',
#     'cnpj': '61.987.234/0001-69',
#     'contato': 'João Lucas Campos',
#     'telefone': '+55 75 9 8355-4777',
#     'email': 'cvieira@example.com',
#     'endereco': {'logradouro': 'Fazenda Rezende, 24',
#      'bairro': 'Liberdade',
#      'cidade': 'Cardoso de Gonçalves',
#      'estado': 'ES',
#      'cep': '01322452'}},
#    {'id': 3,
#     'nome': 'TEIXEIRA - EI',
#     'cnpj': '27.318.940/0001-80',
#     'contato': 'Larissa da Luz',
#     'telefone': '+55 (049) 92127-4587',
#     'email': 'moreiraluana@example.com',
#     'endereco': {'logradouro': 'Passarela de da Cunha, 4',
#      'bairro': 'Copacabana',
#      'cidade': 'da Mata',
#      'estado': 'BA',
#      'cep': '58818970'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e658'),
#   'id': 6,
#   'nome': 'Larissa da Luz',
#   'cpf': '671.453.280-62',
#   'nivel': 'CONFIRMAR',
#   'user_id': 6,
#   'clientes': [{'id': 1,
#     'nome': 'GOMES - ME S/A',
#     'cnpj': '20.547.693/0001-44',
#     'contato': 'Dra. Maria Melo',
#     'telefone': '+55 94 96474 1938',
#     'email': 'rodriguesthales@example.org',
#     'endereco': {'logradouro': 'Núcleo Vieira, 748',
#      'bairro': 'Savassi',
#      'cidade': 'Souza de Fogaça',
#      'estado': 'MS',
#      'cep': '89976069'}},
#    {'id': 2,
#     'nome': 'GOMES S/A - ME',
#     'cnpj': '74.236.915/0001-37',
#     'contato': 'Luigi Moreira',
#     'telefone': '+55 (015) 92304 9483',
#     'email': 'gustavogomes@example.com',
#     'endereco': {'logradouro': 'Vila Silva, 71',
#      'bairro': 'Guarani',
#      'cidade': 'da Cunha',
#      'estado': 'MA',
#      'cep': '72907258'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e659'),
#   'id': 7,
#   'nome': 'Otávio Carvalho',
#   'cpf': '940.163.278-22',
#   'nivel': 'CONFIRMAR',
#   'user_id': 7,
#   'clientes': [{'id': 1,
#     'nome': 'ARAGÃO S.A.',
#     'cnpj': '56.204.187/0001-08',
#     'contato': 'Diogo Rocha',
#     'telefone': '+55 (38) 91924 6919',
#     'email': 'mnascimento@example.org',
#     'endereco': {'logradouro': 'Viela de Oliveira',
#      'bairro': 'São Gonçalo',
#      'cidade': 'Rocha do Amparo',
#      'estado': 'GO',
#      'cep': '19559-814'}},
#    {'id': 2,
#     'nome': 'RODRIGUES LTDA.',
#     'cnpj': '46.972.835/0001-04',
#     'contato': 'Eduarda Vieira',
#     'telefone': '+55 (74) 97451-3278',
#     'email': 'rodriguesana-laura@example.com',
#     'endereco': {'logradouro': 'Colônia de Moraes, 1',
#      'bairro': 'Estoril',
#      'cidade': 'Sales',
#      'estado': 'AC',
#      'cep': '23764-002'}},
#    {'id': 3,
#     'nome': 'CARVALHO S.A. S/A',
#     'cnpj': '45.098.321/0001-09',
#     'contato': 'Dr. Levi Costela',
#     'telefone': '+55 (58) 9 5351-3504',
#     'email': 'erodrigues@example.org',
#     'endereco': {'logradouro': 'Pátio Freitas, 7',
#      'bairro': 'Vila Bandeirantes',
#      'cidade': 'Monteiro',
#      'estado': 'MG',
#      'cep': '31552-931'}},
#    {'id': 4,
#     'nome': 'CARVALHO LTDA. S/A',
#     'cnpj': '16.895.420/0001-13',
#     'contato': 'Ana Barros',
#     'telefone': '+55 86 91503-4060',
#     'email': 'isadora69@example.org',
#     'endereco': {'logradouro': 'Condomínio Nogueira, 85',
#      'bairro': 'Etelvina Carneiro',
#      'cidade': 'Costa',
#      'estado': 'SP',
#      'cep': '13792-483'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e65a'),
#   'id': 8,
#   'nome': 'Nicole Moura',
#   'cpf': '568.340.291-33',
#   'nivel': 'CONFIRMAR',
#   'user_id': 8,
#   'clientes': [{'id': 1,
#     'nome': 'CARVALHO - ME',
#     'cnpj': '34.816.905/0001-56',
#     'contato': 'Breno Viana',
#     'telefone': '+55 33 97125-6039',
#     'email': 'caua21@example.org',
#     'endereco': {'logradouro': 'Jardim Silva, 9',
#      'bairro': 'Vila Independencia 3ª Seção',
#      'cidade': 'Souza Alegre',
#      'estado': 'MT',
#      'cep': '96696-305'}},
#    {'id': 2,
#     'nome': 'FERNANDES - ME',
#     'cnpj': '49.218.360/0001-53',
#     'contato': 'João Pedro Almeida',
#     'telefone': '+55 (083) 96709 9544',
#     'email': 'franciscocostela@example.org',
#     'endereco': {'logradouro': 'Esplanada Araújo, 981',
#      'bairro': 'Beija Flor',
#      'cidade': 'da Cunha do Campo',
#      'estado': 'AM',
#      'cep': '67223-631'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e65b'),
#   'id': 9,
#   'nome': 'João Silveira',
#   'cpf': '693.257.084-00',
#   'nivel': 'CONFIRMAR',
#   'user_id': 9,
#   'clientes': [{'id': 1,
#     'nome': 'DA COSTA - ME',
#     'cnpj': '86.320.791/0001-52',
#     'contato': 'Caio da Rosa',
#     'telefone': '+55 (090) 92839 7868',
#     'email': 'rferreira@example.org',
#     'endereco': {'logradouro': 'Quadra de da Mota, 54',
#      'bairro': 'Alto Vera Cruz',
#      'cidade': 'Cavalcanti Grande',
#      'estado': 'RO',
#      'cep': '24732-321'}},
#    {'id': 2,
#     'nome': 'DIAS S.A. E FILHOS',
#     'cnpj': '21.053.784/0001-96',
#     'contato': 'Sra. Marcela Gomes',
#     'telefone': '+55 11 94433 2894',
#     'email': 'anovaes@example.net',
#     'endereco': {'logradouro': 'Morro Leandro Fogaça, 52',
#      'bairro': 'Chácara Leonina',
#      'cidade': 'Peixoto',
#      'estado': 'PB',
#      'cep': '46226-973'}},
#    {'id': 3,
#     'nome': 'FERREIRA PEREIRA LTDA. E FILHOS',
#     'cnpj': '75.681.342/0001-13',
#     'contato': 'Ryan Carvalho',
#     'telefone': '+55 82 99176 0009',
#     'email': 'davi-lucas18@example.com',
#     'endereco': {'logradouro': 'Fazenda Nunes, 10',
#      'bairro': 'Vista Alegre',
#      'cidade': 'Teixeira da Mata',
#      'estado': 'CE',
#      'cep': '65301843'}},
#    {'id': 4,
#     'nome': 'PEIXOTO S.A.',
#     'cnpj': '04.687.159/0001-87',
#     'contato': 'Vitor Hugo Campos',
#     'telefone': '+55 (098) 90654-7362',
#     'email': 'aliciada-costa@example.com',
#     'endereco': {'logradouro': 'Setor de Farias, 54',
#      'bairro': 'Pindura Saia',
#      'cidade': 'Melo de Melo',
#      'estado': 'SC',
#      'cep': '85473495'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e65c'),
#   'id': 10,
#   'nome': 'Lara da Rocha',
#   'cpf': '054.896.321-51',
#   'nivel': 'CONFIRMAR',
#   'user_id': 10,
#   'clientes': [{'id': 1,
#     'nome': 'MORAES PORTO - EI LTDA.',
#     'cnpj': '40.536.297/0001-29',
#     'contato': 'Sra. Nina Cunha',
#     'telefone': '+55 27 9 1165 3599',
#     'email': 'grezende@example.org',
#     'endereco': {'logradouro': 'Favela Jesus, 84',
#      'bairro': 'Padre Eustáquio',
#      'cidade': 'da Mata',
#      'estado': 'RO',
#      'cep': '12285163'}},
#    {'id': 2,
#     'nome': 'NUNES - ME',
#     'cnpj': '75.983.426/0001-01',
#     'contato': 'Camila Martins',
#     'telefone': '+55 (000) 94998-4223',
#     'email': 'cardosofernanda@example.com',
#     'endereco': {'logradouro': 'Rua Juliana Monteiro, 22',
#      'bairro': 'Marieta 3ª Seção',
#      'cidade': 'Ferreira',
#      'estado': 'MA',
#      'cep': '09702864'}},
#    {'id': 3,
#     'nome': 'CARVALHO - ME',
#     'cnpj': '96.571.438/0001-07',
#     'contato': 'Lavínia Costa',
#     'telefone': '+55 (069) 92817-0957',
#     'email': 'lcaldeira@example.com',
#     'endereco': {'logradouro': 'Praia Santos, 57',
#      'bairro': 'Vila Antena Montanhês',
#      'cidade': 'Cunha',
#      'estado': 'TO',
#      'cep': '90002284'}},
#    {'id': 4,
#     'nome': 'REZENDE TEIXEIRA - EI - EI',
#     'cnpj': '34.762.501/0001-27',
#     'contato': 'Pietro Duarte',
#     'telefone': '+55 68 9 5739-8333',
#     'email': 'fariasian@example.org',
#     'endereco': {'logradouro': 'Viela de Caldeira, 7',
#      'bairro': 'Vila Barragem Santa Lúcia',
#      'cidade': 'Pinto do Galho',
#      'estado': 'RR',
#      'cep': '53373-168'}},
#    {'id': 5,
#     'nome': 'NASCIMENTO LIMA - EI - EI',
#     'cnpj': '95.137.206/0001-74',
#     'contato': 'Erick Cardoso',
#     'telefone': '+55 (23) 91550-8912',
#     'email': 'rpeixoto@example.org',
#     'endereco': {'logradouro': 'Condomínio Fernandes, 79',
#      'bairro': 'Alto Dos Pinheiros',
#      'cidade': 'da Rosa do Galho',
#      'estado': 'SC',
#      'cep': '43217301'}}]},
#  {'_id': ObjectId('6636a5a6bf67c4821d38e65d'),
#   'id': 11,
#   'nome': 'Rafael Sales',
#   'cpf': '067.928.543-10',
#   'nivel': 'CONFIRMAR',
#   'user_id': 11,
#   'clientes': [{'id': 1,
#     'nome': 'COSTELA GONÇALVES S.A. LTDA.',
#     'cnpj': '59.016.283/0001-02',
#     'contato': 'Eduarda Souza',
#     'telefone': '+55 16 99168 7682',
#     'email': 'gustavo-henriquejesus@example.com',
#     'endereco': {'logradouro': 'Loteamento de Moreira, 187',
#      'bairro': 'São Vicente',
#      'cidade': 'da Mata',
#      'estado': 'RO',
#      'cep': '49602211'}},
#    {'id': 2,
#     'nome': 'ALVES ROCHA S.A. S.A.',
#     'cnpj': '87.145.630/0001-32',
#     'contato': 'Luigi da Cunha',
#     'telefone': '+55 13 90701-4834',
#     'email': 'mjesus@example.org',
#     'endereco': {'logradouro': 'Largo Larissa Fogaça, 50',
#      'bairro': 'Vila Santa Rosa',
#      'cidade': 'Carvalho',
#      'estado': 'RN',
#      'cep': '56262-162'}}]}]

# %%
# estoques = list(db['venda_estoque'].find())

estoques = {}
for e in db['venda_estoque'].find():
  estoques[f"P{e['id']:02}"] = e
estoques
# Out:
# {'P01': {'_id': ObjectId('66399227489da24ed18e99c7'),
#   'id': 1,
#   'produto': {'marca': {'nome': 'Bot-Art'},
#    'categoria': {'titulo': 'Xicaras'},
#    'descricao': 'Leiteira Texas Media 550ml'},
#   'quantidade': 1000,
#   'preco_compra': 14.925,
#   'preco_venda': 29.85},
#  'P02': {'_id': ObjectId('66399227489da24ed18e99c8'),
#   'id': 2,
#   'produto': {'marca': {'nome': 'Bot-Art'},
#    'categoria': {'titulo': 'Xicaras'},
#    'descricao': 'Xicara Café c/ pires Veneza'},
#   'quantidade': 1000,
#   'preco_compra': 7.345,
#   'preco_venda': 14.69},
#  'P03': {'_id': ObjectId('66399227489da24ed18e99c9'),
#   'id': 3,
#   'produto': {'marca': {'nome': 'Renata'},
#    'categoria': {'titulo': 'Biscoitos, Bolos e Torradas em Sache'},
#    'descricao': 'Sache Biscoito AMANTEIGADO COCO RENATA SACHÊ 9G 2X2 CAIXA 280 und'},
#   'quantidade': 1000,
#   'preco_compra': 43.935,
#   'preco_venda': 87.87},
#  'P04': {'_id': ObjectId('66399227489da24ed18e99ca'),
#   'id': 4,
#   'produto': {'marca': {'nome': 'Renata'},
#    'categoria': {'titulo': 'Biscoitos, Bolos e Torradas em Sache'},
#    'descricao': 'Sache de Biscoito Maria RENATA 11G CAIXA 180 UNIDADES'},
#   'quantidade': 1000,
#   'preco_compra': 34.1,
#   'preco_venda': 68.2},
#  'P05': {'_id': ObjectId('66399227489da24ed18e99cb'),
#   'id': 5,
#   'produto': {'marca': {'nome': 'Atlântica'},
#    'categoria': {'titulo': 'Toalha Personalizada Para Hotelaria'},
#    'descricao': 'Toalha de Banho Bordada Turquesa cx 10 und'},
#   'quantidade': 1000,
#   'preco_compra': 272.115,
#   'preco_venda': 544.23},
#  'P06': {'_id': ObjectId('66399227489da24ed18e99cc'),
#   'id': 6,
#   'produto': {'marca': {'nome': 'Abdouni'},
#    'categoria': {'titulo': 'Capas Protetoras'},
#    'descricao': 'Capa Protetora de Travesseiro Scothgard c/ziper- Repelente a Água Cx 10 und'},
#   'quantidade': 1000,
#   'preco_compra': 106.345,
#   'preco_venda': 212.69},
#  'P07': {'_id': ObjectId('66399227489da24ed18e99cd'),
#   'id': 7,
#   'produto': {'marca': {'nome': 'Abdouni'},
#    'categoria': {'titulo': 'Capas Protetoras'},
#    'descricao': 'Capa Protetora de Travesseiro Laminado Jade - Cx 10 und'},
#   'quantidade': 1000,
#   'preco_compra': 60.58,
#   'preco_venda': 121.16},
#  'P08': {'_id': ObjectId('66399227489da24ed18e99ce'),
#   'id': 8,
#   'produto': {'marca': {'nome': 'Abdouni'},
#    'categoria': {'titulo': 'Capas Protetoras'},
#    'descricao': 'Capa Protetora Colchão Impermeável Laminado Sleep Jade'},
#   'quantidade': 1000,
#   'preco_compra': 23.715,
#   'preco_venda': 47.43},
#  'P09': {'_id': ObjectId('66399227489da24ed18e99cf'),
#   'id': 9,
#   'produto': {'marca': {'nome': 'Naturallys'},
#    'categoria': {'titulo': 'Mini Sabonete Para Hotel'},
#    'descricao': 'Mini Sabonete Hotel Redondo Naturallys Plissado 20g cx 500 und'},
#   'quantidade': 1000,
#   'preco_compra': 281.655,
#   'preco_venda': 563.31},
#  'P10': {'_id': ObjectId('66399227489da24ed18e99d0'),
#   'id': 10,
#   'produto': {'marca': {'nome': 'ParaHotel Maxi'},
#    'categoria': {'titulo': 'Colchao de Hotel Mola'},
#    'descricao': 'Colchão Mola ParaHotel Maxi Queen 158x198x27 por'},
#   'quantidade': 1000,
#   'preco_compra': 1017.5,
#   'preco_venda': 2035.0},
#  'P11': {'_id': ObjectId('66399227489da24ed18e99d1'),
#   'id': 11,
#   'produto': {'marca': {'nome': 'ParaHotel Maxi'},
#    'categoria': {'titulo': 'Colchao de Hotel Mola'},
#    'descricao': 'Colchão Mola ParaHotel Maxi Solteiro 78x188x27 com Velcro por'},
#   'quantidade': 1000,
#   'preco_compra': 598.5,
#   'preco_venda': 1197.0},
#  'P12': {'_id': ObjectId('66399227489da24ed18e99d2'),
#   'id': 12,
#   'produto': {'marca': {'nome': 'BaClean'},
#    'categoria': {'titulo': 'Aromatizante Ar Condicionado'},
#    'descricao': 'Pastilha Bacterida e Aromatizante Ar Condicionado Cx 10 und'},
#   'quantidade': 1000,
#   'preco_compra': 80.7,
#   'preco_venda': 161.4},
#  'P13': {'_id': ObjectId('66399227489da24ed18e99d3'),
#   'id': 13,
#   'produto': {'marca': {'nome': 'ParaHotel'},
#    'categoria': {'titulo': 'Sabonetes e Amenities Para Hotelaria'},
#    'descricao': 'Pente Plastico Personalizado Para Motel Descartavel - Cx 100 und'},
#   'quantidade': 1000,
#   'preco_compra': 53.5,
#   'preco_venda': 107.0},
#  'P14': {'_id': ObjectId('66399227489da24ed18e99d4'),
#   'id': 14,
#   'produto': {'marca': {'nome': 'ParaHotel'},
#    'categoria': {'titulo': 'Sabonetes e Amenities Para Hotelaria'},
#    'descricao': 'Kit Sais de Banho Personalizado 40 g - Sortido Cx 100 und'},
#   'quantidade': 1000,
#   'preco_compra': 215.0,
#   'preco_venda': 430.0},
#  'P15': {'_id': ObjectId('66399227489da24ed18e99d5'),
#   'id': 15,
#   'produto': {'marca': {'nome': 'ParaHotel'},
#    'categoria': {'titulo': 'Sabonetes e Amenities Para Hotelaria'},
#    'descricao': 'Espuma de Banho Personalizado em Frasco 30 ml - Cx 100 und'},
#   'quantidade': 1000,
#   'preco_compra': 86.645,
#   'preco_venda': 173.29},
#  'P16': {'_id': ObjectId('66399227489da24ed18e99d6'),
#   'id': 16,
#   'produto': {'marca': {'nome': 'ParaHotel'},
#    'categoria': {'titulo': 'Sabonetes e Amenities Para Hotelaria'},
#    'descricao': 'Kit Amenities Personalizado Sabonete 15 g e Shampoo 30 ml Hotel 100 und'},
#   'quantidade': 1000,
#   'preco_compra': 171.475,
#   'preco_venda': 342.95},
#  'P17': {'_id': ObjectId('66399227489da24ed18e99d7'),
#   'id': 17,
#   'produto': {'marca': {'nome': 'Abdouni'},
#    'categoria': {'titulo': 'Lençol de Hotel, Cobertores e AFins'},
#    'descricao': 'Lençol Percal 180 fios Linha Esmeralda 60/40 Super Queen Cx 10 und por'},
#   'quantidade': 1000,
#   'preco_compra': 515.5,
#   'preco_venda': 1031.0},
#  'P18': {'_id': ObjectId('66399227489da24ed18e99d8'),
#   'id': 18,
#   'produto': {'marca': {'nome': 'Abdouni'},
#    'categoria': {'titulo': 'Lençol de Hotel, Cobertores e AFins'},
#    'descricao': 'Lençol Percal 180 fios Linha Esmeralda 60/40 Queen Cx 10 und'},
#   'quantidade': 1000,
#   'preco_compra': 481.5,
#   'preco_venda': 963.0},
#  'P19': {'_id': ObjectId('66399227489da24ed18e99d9'),
#   'id': 19,
#   'produto': {'marca': {'nome': 'Atlântica'},
#    'categoria': {'titulo': 'Toalha Para Hotel'},
#    'descricao': 'Kit 20 Toalhas De Rosto Para Hotel, Motel, Pousada'},
#   'quantidade': 1000,
#   'preco_compra': 176.5,
#   'preco_venda': 353.0}}

# %%
# from pprint import pprint

itens_pedido = []
id = 0
nota = teste.iloc[0, 0]
for index, row in teste.iterrows():
  if nota != row['nota']:
    # pprint(itens_pedido)
    print(itens_pedido)
    itens_pedido = []
    id = 0
    nota = row['nota']
    # print(estoques[row['produto']])
    # print(row['nota'], row['data'], row['horario'], row['produto'], row['quantidade'])

  id += 1
  estoque = estoques[row['produto']]
  item = {
    "nota": nota,
    "id": id,
    "produto": estoque['produto'],
    "preco_compra": estoque['preco_compra'],
    "preco_venda": estoque['preco_venda'],
    "quantidade": row['quantidade'],
    "total": round(row['quantidade'] * estoque['preco_venda'], 2)
  }
  itens_pedido.append(item)
  # print(item)
# pprint(itens_pedido)
print(itens_pedido)
# Out:
# [{'nota': '20230101-0', 'id': 1, 'produto': {'marca': {'nome': 'Renata'}, 'categoria': {'titulo': 'Biscoitos, Bolos e Torradas em Sache'}, 'descricao': 'Sache de Biscoito Maria RENATA 11G CAIXA 180 UNIDADES'}, 'preco_compra': 34.1, 'preco_venda': 68.2, 'quantidade': 34, 'total': 2318.8}, {'nota': '20230101-0', 'id': 2, 'produto': {'marca': {'nome': 'Renata'}, 'categoria': {'titulo': 'Biscoitos, Bolos e Torradas em Sache'}, 'descricao': 'Sache de Biscoito Maria RENATA 11G CAIXA 180 UNIDADES'}, 'preco_compra': 34.1, 'preco_venda': 68.2, 'quantidade': 2, 'total': 136.4}, {'nota': '20230101-0', 'id': 3, 'produto': {'marca': {'nome': 'Atlântica'}, 'categoria': {'titulo': 'Toalha Para Hotel'}, 'descricao': 'Kit 20 Toalhas De Rosto Para Hotel, Motel, Pousada'}, 'preco_compra': 176.5, 'preco_venda': 353.0, 'quantidade': 4, 'total': 1412.0}, {'nota': '20230101-0', 'id': 4, 'produto': {'marca': {'nome': 'Bot-Art'}, 'categoria': {'titulo': 'Xicaras'}, 'descricao': 'Xicara Café c/ pires Veneza'}, 'preco_compra': 7.345, 'preco_venda': 14.69, 'quantidade': 21, 'total': 308.49}]
# [{'nota': '20230101-1', 'id': 1, 'produto': {'marca': {'nome': 'Abdouni'}, 'categoria': {'titulo': 'Lençol de Hotel, Cobertores e AFins'}, 'descricao': 'Lençol Percal 180 fios Linha Esmeralda 60/40 Super Queen Cx 10 und por'}, 'preco_compra': 515.5, 'preco_venda': 1031.0, 'quantidade': 4, 'total': 4124.0}, {'nota': '20230101-1', 'id': 2, 'produto': {'marca': {'nome': 'Bot-Art'}, 'categoria': {'titulo': 'Xicaras'}, 'descricao': 'Xicara Café c/ pires Veneza'}, 'preco_compra': 7.345, 'preco_venda': 14.69, 'quantidade': 13, 'total': 190.97}]
# [{'nota': '20230101-2', 'id': 1, 'produto': {'marca': {'nome': 'Bot-Art'}, 'categoria': {'titulo': 'Xicaras'}, 'descricao': 'Xicara Café c/ pires Veneza'}, 'preco_compra': 7.345, 'preco_venda': 14.69, 'quantidade': 10, 'total': 146.9}]
# [{'nota': '20230101-3', 'id': 1, 'produto': {'marca': {'nome': 'Abdouni'}, 'categoria': {'titulo': 'Capas Protetoras'}, 'descricao': 'Capa Protetora de Travesseiro Scothgard c/ziper- Repelente a Água Cx 10 und'}, 'preco_compra': 106.345, 'preco_venda': 212.69, 'quantidade': 16, 'total': 3403.04}, {'nota': '20230101-3', 'id': 2, 'produto': {'marca': {'nome': 'Abdouni'}, 'categoria': {'titulo': 'Capas Protetoras'}, 'descricao': 'Capa Protetora de Travesseiro Laminado Jade - Cx 10 und'}, 'preco_compra': 60.58, 'preco_venda': 121.16, 'quantidade': 22, 'total': 2665.52}, {'nota': '20230101-3', 'id': 3, 'produto': {'marca': {'nome': 'Abdouni'}, 'categoria': {'titulo': 'Capas Protetoras'}, 'descricao': 'Capa Protetora Colchão Impermeável Laminado Sleep Jade'}, 'preco_compra': 23.715, 'preco_venda': 47.43, 'quantidade': 5, 'total': 237.15}]
# []
